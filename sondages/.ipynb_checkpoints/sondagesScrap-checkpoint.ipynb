# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import sys
import warnings
warnings.filterwarnings('ignore')

URL = "https://fr.wikipedia.org/wiki/Liste_de_sondages_sur_l'%C3%A9lection_pr%C3%A9sidentielle_fran%C3%A7aise_de_2017#2016"

def loadHTML(URL):
    resultats = requests.get(URL)
    return BeautifulSoup(resultats.text, 'html.parser')


def loadPandas(URL):
    tables = loadHTML(URL).findAll("table")

    dfF = pd.DataFrame()
    dfFs = pd.DataFrame()
    
    #Pour chaque table de wikipedia :
    for table in tables :
        lignes = table.findAll("tr")

        #On récupère le nom de chaque colonne :
        colonnes = []
        for elem in lignes[0].findAll("th"):
            if elem.find("a") is None :
                colonnes.append(elem.text)
            else :
                if(elem.find("a").text != ""):
                    colonnes.append(elem.find("a").text)
        if len(colonnes) < 7:
            for elem in lignes[2].findAll("th"):
                a=3
                colonnes.append(elem.text)

        #On crée un pandas dataframe pour stocker nos table :
        df = pd.DataFrame(columns = colonnes)

        #print(len(colonnes))

        nbRowspan = 0
        rowspan = []
        rowspanMil = []
        
        #our chaque ligne de notre table :
        for j,ligne in enumerate(lignes[2:]):
            line = list(np.zeros(len(colonnes)))
            line = ["/" for item in line]
            
            #lorsque certains éléments de notre tableau occupent plusieurs lignes
            for i,item in enumerate(rowspanMil):
                if item[0] > 1 : 
                    line[item[1]] = item[2]
                    item[0] -= 1
                    
            for i,elem in enumerate(ligne.findAll("td")):
                while line[i] != "/":
                    i+=1
                
                if elem.has_attr("rowspan"):
                    nbRowspan = int(elem["rowspan"])
                    if nbRowspan >1:
                        try : 
                            rowspanMil.append([nbRowspan, i, float(elem.text.replace("%", "").replace(",",".").replace("<",""))])
                        except Exception as e : 
                            rowspanMil.append([nbRowspan, i, (elem.text.replace("%", "").replace(",",".").replace("<",""))])
                try:
                    line[i] = (float(elem.text.replace("%", "").replace(",",".").replace("<","")))
                except Exception as e :
                    line[i] = (elem.text.replace("%", "").replace(",",".").replace("<",""))
            
            if len(line) > len(colonnes) - 3 :
                df.loc[j] = line
            #print(df)
        
        #2ème tour : 
        if len(colonnes) < 7  :
            dfFs = dfFs.append(df)
        #1er tour : 
        else : 
            dfF = dfF.append(df)
            
    return (dfF, dfFs)


#print(dfF)

# %%
#print(test)
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import cm 
from matplotlib import colors
# %matplotlib inline
import dateparser

dfF, dfFs = loadPandas(URL)

print(dfF)
plt.figure(1)
dfF = dfF.replace(to_replace=["-", "–"], value=" ")

notCandidats = ["Date", "Sondeur", "Échantillon"]

anciensCandidats = ["Alain Juppé", "Bruno Le Maire", "Jean-François Copé", "Nicolas Sarkozy", "Éva Joly"]

print(dfF)
for col in dfF.columns:
    if col not in notCandidats: 
        dfF[col] = dfF[col].map(lambda x: x if isinstance(x, float) else np.nan)

dfF2 = dfF
for col in anciensCandidats: 
    dfF2 = dfF2[dfF2[col].isnull()]
    dfF2 = dfF2.drop(col, axis=1)
    
#print(dfF)
dfF3 = dfF2.groupby(["Date"]).mean().reset_index()


dfF3["Date"] = dfF3["Date"].map(lambda x : x if len(x.split(" ")) < 4 else " ".join(x.split(" ")[-3:]))
dfF3["Date"] = dfF3["Date"].map(lambda x : dateparser.parse(x).date())
dfF3 = dfF3.sort_values('Date', ascending=1)

def dateToString(date):
    if len(str(date.month))==1:
        month = "0"+str(date.month)
    else : 
        month = str(date.month)
        
    if len(str(date.day))==1:
        day = "0"+str(date.day)
    else : 
        day = str(date.day)
    return str(date.year)+month+day

dfF3 = dfF3.round(2)
dfF4 = dfF3


dfF4["date"] = dfF3["Date"].map(lambda x: dateToString(x))
dfF4 = dfF4.drop("Date", axis=1) 

dfF4 = dfF4.set_index("date")
dfF4 = dfF4.dropna(axis=0, how='all')
dfF4 = dfF4.dropna(axis=1, how='all')

dfF4.to_csv("C:\\Users\\Mohamed\\MS BGD\\fil_rouge_lepoint\\Sondages\\sondages1er.csv", sep="\t")

dfF4.to_csv("C:\\Users\\Mohamed\\MS BGD\\fil_rouge_lepoint\\Sondages\\data.tsv", sep="\t")

#print(dfF3[["Manuel Valls", "Date"]])


def plotTable(dfF3):
    coul_a_retirer = ["seashell", "white", "linen", "lavenderblush", 'blanchedalmond', 'moccasin','azure',\
                  'antiquewhite', 'lightyellow', 'whitesmoke', 'lightcoral', 'lightcyan', 'ivory', 'lightslategrey',\
                     'lightsage', 'ghostwhite', 'snow', 'beige', 'lightgray', 'navajowhite']
    color = [col for col in colors.cnames.keys() if col not in coul_a_retirer]
    
    color = ['aquamarine', 'peachpuff', 'darkcyan', 'mediumspringgreen', 'orangered',\
             'chartreuse', 'tomato', 'mediumturquoise', 'dimgray', 'limegreen', 'cornflowerblue',\
             'greenyellow', 'darkgray', 'navy', 'royalblue', 'blue', 'crimson', 'turquoise', 'darkgoldenrod']
    plt.figure(1)
    
    # for col, name in zip(dfF3.drop(["Date"], axis=1), color):
    #     temp = dfF3[dfF3[col].notnull()]
    #     x = range(len(temp["Date"]))
    #     #plt.plot(x,dfF["Nicolas Sarkozy"])
    #     plt.plot(x,temp[col], lw = 1, c=name)
    #     plt.label = col
    
#     x = range(len(dfF3["Date"]))
    plt.xticks(rotation=60)
    for col, name in zip(dfF3.drop(["Date"], axis=1), color):
        if (dfF3[col].notnull().any()):
            temp = dfF3[dfF3[col].notnull()]#print(tempDate)
            plt.plot(temp.Date,temp[col], lw = 1, c=name)
            plt.label = col

    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.xlabel("Date du sondage")
    plt.ylabel("Points par candidats en %")
    plt.title("Evolution de l'intention de vote au premier tour")
    plt.grid(b=True)
    plt.show()
# Out:
#    Alain Juppé Arnaud Montebourg Benoît Hamon Bruno Le Maire Cécile Duflot  \
# 0          NaN               NaN          NaN            NaN           NaN
# 0          NaN               NaN          NaN            NaN           NaN
# 1          NaN               NaN          NaN            NaN           NaN
# 2          NaN               NaN          NaN            NaN           NaN
# 3          NaN               NaN          NaN            NaN           NaN
# 4          NaN               NaN          NaN            NaN           NaN
# 5          NaN               NaN          NaN            NaN           NaN
# 6          NaN               NaN          NaN            NaN           NaN
# 0            –                 –          NaN            NaN             –
# 1            –                 –          NaN            NaN             -
# 2           30                 –          NaN            NaN             -
# 3            –                 –          NaN            NaN             –
# 4            -                 –          NaN            NaN             3
# 5            -                 –          NaN            NaN             3
# 6            -                10          NaN            NaN             4
# 7            -                 –          NaN            NaN             3
# 8           24                 –          NaN            NaN             3
# 9            -                 –          NaN            NaN             3
# 10           –                 –          NaN            NaN             3
# 11          28                 –          NaN            NaN             3
# 12          32                 –          NaN            NaN             4
# 13           –                 –          NaN            NaN             4
# 14           –                 –          NaN            NaN             –
# 15           –                 –          NaN            NaN             3
# 16          30                 –          NaN            NaN             2
# 17           –                 –          NaN            NaN             3
# 0            -                 -          NaN            NaN             3
# 1           23                 -          NaN            NaN             4
# 2            -                 -          NaN            NaN             4
# 3           22                 -          NaN            NaN             3
# ..         ...               ...          ...            ...           ...
# 3           34               NaN          NaN            NaN           NaN
# 4           31               NaN          NaN            NaN           NaN
# 5           26               NaN          NaN            NaN           NaN
# 6            -               NaN          NaN            NaN           NaN
# 7            -               NaN          NaN            NaN           NaN
# 8            -               NaN          NaN            NaN           NaN
# 9            -               NaN          NaN            NaN           NaN
# 10           -               NaN          NaN            NaN           NaN
# 0          NaN                 -          NaN            NaN           NaN
# 1          NaN                 -          NaN            NaN           NaN
# 2          NaN                 -          NaN            NaN           NaN
# 3          NaN                 -          NaN            NaN           NaN
# 4          NaN                 -          NaN            NaN           NaN
# 5          NaN                 6          NaN            NaN           NaN
# 6          NaN                 7          NaN            NaN           NaN
# 7          NaN                 -          NaN            NaN           NaN
# 8          NaN                 -          NaN            NaN           NaN
# 9          NaN                 5          NaN            NaN           NaN
# 10         NaN                 -          NaN            NaN           NaN
# 11         NaN                 6          NaN            NaN           NaN
# 0          NaN                 -            -            NaN           NaN
# 1          NaN                 6            -            NaN           NaN
# 2          NaN                 -            4            NaN           NaN
# 3          NaN                 -            -            NaN           NaN
# 4          NaN               6.5            -            NaN           NaN
# 5          NaN                 -            -            NaN           NaN
# 6          NaN                 -            -            NaN           NaN
# 7          NaN                 -            -            NaN           NaN
# 8          NaN                 6            -            NaN           NaN
# 9          NaN                 7            -            NaN           NaN
#
#                       Date Emmanuel Macron François Asselineau  \
# 0     9 au 12 octobre 2012             NaN                 NaN
# 0      11 au 15 avril 2013             NaN                 NaN
# 1      16 au 17 avril 2013             NaN                 NaN
# 2      26 au 28 avril 2013             NaN                 NaN
# 3      26 au 29 avril 2013             NaN                 NaN
# 4      26 au 29 avril 2013             NaN                 NaN
# 5      26 au 29 avril 2013             NaN                 NaN
# 6          2 et 3 mai 2013             NaN                 NaN
# 0      11 au 13 avril 2014             NaN                 NaN
# 1      15 au 18 avril 2014             NaN                 NaN
# 2      15 au 18 avril 2014             NaN                 NaN
# 3      15 au 18 avril 2014             NaN                 NaN
# 4    21 au 22 juillet 2014             NaN                 NaN
# 5    21 au 22 juillet 2014             NaN                 NaN
# 6    21 au 22 juillet 2014             NaN                 NaN
# 7    3 au 4 septembre 2014             NaN                 NaN
# 8    3 au 4 septembre 2014             NaN                 NaN
# 9    3 au 4 septembre 2014             NaN                 NaN
# 10   28 au 30 octobre 2014             NaN                 NaN
# 11   28 au 30 octobre 2014             NaN                 NaN
# 12   28 au 30 octobre 2014             NaN                 NaN
# 13   28 au 30 octobre 2014             NaN                 NaN
# 14   28 au 30 octobre 2014             NaN                 NaN
# 15   28 au 30 octobre 2014             NaN                 NaN
# 16   28 au 30 octobre 2014             NaN                 NaN
# 17   28 au 30 octobre 2014             NaN                 NaN
# 0    21 au 23 janvier 2015             NaN                 NaN
# 1    21 au 23 janvier 2015             NaN                 NaN
# 2    21 au 23 janvier 2015             NaN                 NaN
# 3    21 au 23 janvier 2015             NaN                 NaN
# ..                     ...             ...                 ...
# 3    8 au 13 novembre 2016               -                 NaN
# 4    8 au 13 novembre 2016              10                 NaN
# 5   16 et 17 novembre 2016              14                 NaN
# 6   16 et 17 novembre 2016              16                 NaN
# 7   16 et 17 novembre 2016              15                 NaN
# 8         25 novembre 2016              13                 NaN
# 9         27 novembre 2016              14                 NaN
# 10        27 novembre 2016              13                 NaN
# 0         28 novembre 2016              15                 NaN
# 1         28 novembre 2016              17                 NaN
# 2         28 novembre 2016               -                 NaN
# 3         28 novembre 2016              13                 NaN
# 4         28 novembre 2016              15                 NaN
# 5         28 novembre 2016              16                 NaN
# 6         28 novembre 2016            17.5                 NaN
# 7   28 et 29 novembre 2016              16                 NaN
# 8   28 et 29 novembre 2016              14                 NaN
# 9   28 et 29 novembre 2016              17                 NaN
# 10  28 au 30 novembre 2016              15                 NaN
# 11  28 au 30 novembre 2016              17                 NaN
# 0     2 et 3 décembre 2016            13.5                 NaN
# 1     2 et 3 décembre 2016              16                 NaN
# 2     2 et 3 décembre 2016              16                 NaN
# 3     2 au 4 décembre 2016              14                 NaN
# 4     2 au 4 décembre 2016              19                 NaN
# 5     2 au 4 décembre 2016               -                 NaN
# 6     2 au 7 décembre 2016              13                 NaN
# 7     2 au 7 décembre 2016              15                 NaN
# 8     2 au 7 décembre 2016              16                 NaN
# 9     2 au 7 décembre 2016              18                 NaN
#
#    François Bayrou François Fillon   ...    Nicolas Sarkozy  \
# 0                7             NaN   ...               29.5
# 0               10               -   ...                 30
# 1               11               -   ...                 28
# 2                7               -   ...                 34
# 3               10               -   ...                 32
# 4               13              16   ...                  -
# 5               14               -   ...                  -
# 6               10               -   ...                 29
# 0                8               –   ...                 29
# 1               12               -   ...                 31
# 2               10               -   ...                  –
# 3               13              22   ...                  -
# 4               13               –   ...                 25
# 5               12               –   ...                 25
# 6               16               –   ...                 26
# 7               14              17   ...                  –
# 8               11               –   ...                  –
# 9               12               –   ...                 25
# 10              13               –   ...                 26
# 11              10               –   ...                  –
# 12               –               –   ...
# 13              16              18   ...                  -
# 14              14               –   ...                 26
# 15              14               –   ...                 27
# 16              10               –   ...                  –
# 17              13               –   ...                 27
# 0                9             NaN   ...                 23
# 1                7             NaN   ...                  -
# 2                7             NaN   ...                 23
# 3                7             NaN   ...                  -
# ..             ...             ...   ...                ...
# 3                -               -   ...                  -
# 4                -               -   ...                  -
# 5                -               -   ...                  -
# 6              8.5               -   ...               17.5
# 7              5.5              20   ...                  -
# 8                6              32   ...                  -
# 9                6              26   ...                  -
# 10               7              26   ...                  -
# 0                6              29   ...                NaN
# 1                -              30   ...                NaN
# 2                -              34   ...                NaN
# 3                6              28   ...                NaN
# 4                -              29   ...                NaN
# 5                6              29   ...                NaN
# 6                -              31   ...                NaN
# 7                6              30   ...                NaN
# 8                5              31   ...                NaN
# 9                5              31   ...                NaN
# 10             5.5              28   ...                NaN
# 11               6              29   ...                NaN
# 0                7            27.5   ...                NaN
# 1                8              28   ...                NaN
# 2                9              28   ...                NaN
# 3                6              24   ...                NaN
# 4                8              23   ...                NaN
# 5                -              29   ...                NaN
# 6                6              26   ...                NaN
# 7                -              27   ...                NaN
# 8                7              27   ...                NaN
# 9                -              29   ...                NaN
#
#    Olivier Besancenot Philippe Poutou Philippe de Villiers Rama Yade  \
# 0                 NaN             1.5                  NaN       NaN
# 0                 NaN               1                  NaN       NaN
# 1                 NaN             0.5                  NaN       NaN
# 2                 NaN               1                  NaN       NaN
# 3                 NaN               1                  NaN       NaN
# 4                 NaN               1                  NaN       NaN
# 5                 NaN               1                  NaN       NaN
# 6                 NaN               1                  NaN       NaN
# 0                 NaN               2                  NaN       NaN
# 1                 NaN             1.5                  NaN       NaN
# 2                 NaN             1.5                  NaN       NaN
# 3                 NaN             1.5                  NaN       NaN
# 4                 NaN               1                  NaN       NaN
# 5                 NaN               1                  NaN       NaN
# 6                 NaN               1                  NaN       NaN
# 7                 NaN               1                  NaN       NaN
# 8                 NaN               1                  NaN       NaN
# 9                 NaN               1                  NaN       NaN
# 10                NaN             1.5                  NaN       NaN
# 11                NaN             1.5                  NaN       NaN
# 12                NaN             1.5                  NaN       NaN
# 13                NaN             1.5                  NaN       NaN
# 14                NaN             1.5                  NaN       NaN
# 15                NaN             1.5                  NaN       NaN
# 16                NaN             1.5                  NaN       NaN
# 17                NaN             1.5                  NaN       NaN
# 0                   -               2                    -       NaN
# 1                   -               2                    -       NaN
# 2                   -               1                    -       NaN
# 3                   -             1.5                    -       NaN
# ..                ...             ...                  ...       ...
# 3                 NaN             1.5                  NaN       NaN
# 4                 NaN             1.5                  NaN       NaN
# 5                 NaN             1.5                  NaN       NaN
# 6                 NaN             1.5                  NaN       NaN
# 7                 NaN             1.5                  NaN       NaN
# 8                 NaN               1                  NaN       NaN
# 9                 NaN               1                  NaN       NaN
# 10                NaN               1                  NaN       NaN
# 0                 NaN               1                  NaN       NaN
# 1                 NaN               1                  NaN       NaN
# 2                 NaN             1.5                  NaN       NaN
# 3                 NaN               1                  NaN       NaN
# 4                 NaN               1                  NaN       NaN
# 5                 NaN               1                  NaN       NaN
# 6                 NaN               1                  NaN       NaN
# 7                 NaN               1                  NaN       NaN
# 8                 NaN               1                  NaN       NaN
# 9                 NaN               1                  NaN       NaN
# 10                NaN               1                  NaN       NaN
# 11                NaN               1                  NaN       NaN
# 0                 NaN               1                  NaN       NaN
# 1                 NaN               1                  NaN       NaN
# 2                 NaN               1                  NaN       NaN
# 3                 NaN             0.5                  NaN       NaN
# 4                 NaN               1                  NaN       NaN
# 5                 NaN               1                  NaN       NaN
# 6                 NaN               1                  NaN       NaN
# 7                 NaN               1                  NaN       NaN
# 8                 NaN               1                  NaN       NaN
# 9                 NaN               1                  NaN       NaN
#
#                        Sondeur Sylvia Pinel Yannick Jadot Échantillon Éva Joly
# 0                         Ifop          NaN           NaN       1 607        2
# 0                         Ifop          NaN           NaN       1 967      1.5
# 1                   OpinionWay          NaN           NaN       1 022        3
# 2                          CSA          NaN           NaN       1 027        2
# 3        Future Thinking - SSI          NaN           NaN       1 000        2
# 4        Future Thinking - SSI          NaN           NaN       1 000        2
# 5        Future Thinking - SSI          NaN           NaN       1 000        2
# 6                          BVA          NaN           NaN       1 086        2
# 0                  Opinion Way          NaN           NaN       1 023        2
# 1                         Ifop          NaN           NaN         998        3
# 2                         Ifop          NaN           NaN         998        3
# 3                         Ifop          NaN           NaN         998        3
# 4                         Ifop          NaN           NaN         947        –
# 5                         Ifop          NaN           NaN         947        –
# 6                         Ifop          NaN           NaN         947        –
# 7                         Ifop          NaN           NaN         994        –
# 8                         Ifop          NaN           NaN         994        –
# 9                         Ifop          NaN           NaN         994        –
# 10                        Ifop          NaN           NaN       1 382        –
# 11                        Ifop          NaN           NaN       1 382        –
# 12                        Ifop          NaN           NaN       1 382        –
# 13                        Ifop          NaN           NaN       1 382        –
# 14                        Ifop          NaN           NaN       1 382        –
# 15                        Ifop          NaN           NaN       1 382        –
# 16                        Ifop          NaN           NaN       1 382        –
# 17                        Ifop          NaN           NaN       1 382        –
# 0                         Ifop          NaN           NaN       1 051      NaN
# 1                         Ifop          NaN           NaN       1 051      NaN
# 2                         Ifop          NaN           NaN       1 051      NaN
# 3                         Ifop          NaN           NaN       1 051      NaN
# ..                         ...          ...           ...         ...      ...
# 3   Cevipof Ipsos-Sopra Steria          NaN             4      18 200      NaN
# 4   Cevipof Ipsos-Sopra Steria          NaN             3      18 200      NaN
# 5                Ifop-Fiducial          NaN           2.5         979      NaN
# 6                Ifop-Fiducial          NaN           2.5         979      NaN
# 7                Ifop-Fiducial          NaN             3         979      NaN
# 8                        Odoxa          NaN             2         844      NaN
# 9                       Harris          NaN             3        6093      NaN
# 10                      Harris          NaN             2        6093      NaN
# 0     Kantar Sofres - OnePoint            1             2        1011      NaN
# 1     Kantar Sofres - OnePoint            1             2        1011      NaN
# 2     Kantar Sofres - OnePoint            1             3        1011      NaN
# 3     Kantar Sofres - OnePoint          0.5             2        1011      NaN
# 4     Kantar Sofres - OnePoint          0.5           2.5        1011      NaN
# 5     Kantar Sofres - OnePoint            1           1.5        1011      NaN
# 6     Kantar Sofres - OnePoint            1             2        1011      NaN
# 7                        Elabe            -           1.5        1000      NaN
# 8                        Elabe            -           1.5        1000      NaN
# 9                        Elabe            -           1.5        1000      NaN
# 10               Ifop-Fiducial          0.5             2        1882      NaN
# 11               Ifop-Fiducial            1           1.5        1882      NaN
# 0                Ifop-Fiducial            0             2        1401      NaN
# 1                Ifop-Fiducial          0.5           1.5        1401      NaN
# 2                Ifop-Fiducial            0           1.5        1401      NaN
# 3                          BVA          0.5             2         934      NaN
# 4                          BVA          0.5             2         934      NaN
# 5                          BVA          0.5           2.5         934      NaN
# 6   Cevipof Ipsos-Sopra Steria          0.5           2.5       18013      NaN
# 7   Cevipof Ipsos-Sopra Steria          0.5           2.5       18013      NaN
# 8   Cevipof Ipsos-Sopra Steria          0.5           2.5       18013      NaN
# 9   Cevipof Ipsos-Sopra Steria          0.5           2.5       18013      NaN
#
# [230 rows x 31 columns]
#    Alain Juppé Arnaud Montebourg Benoît Hamon Bruno Le Maire Cécile Duflot  \
# 0          NaN               NaN          NaN            NaN           NaN
# 0          NaN               NaN          NaN            NaN           NaN
# 1          NaN               NaN          NaN            NaN           NaN
# 2          NaN               NaN          NaN            NaN           NaN
# 3          NaN               NaN          NaN            NaN           NaN
# 4          NaN               NaN          NaN            NaN           NaN
# 5          NaN               NaN          NaN            NaN           NaN
# 6          NaN               NaN          NaN            NaN           NaN
# 0                                         NaN            NaN
# 1                                         NaN            NaN
# 2           30                            NaN            NaN
# 3                                         NaN            NaN
# 4                                         NaN            NaN             3
# 5                                         NaN            NaN             3
# 6                             10          NaN            NaN             4
# 7                                         NaN            NaN             3
# 8           24                            NaN            NaN             3
# 9                                         NaN            NaN             3
# 10                                        NaN            NaN             3
# 11          28                            NaN            NaN             3
# 12          32                            NaN            NaN             4
# 13                                        NaN            NaN             4
# 14                                        NaN            NaN
# 15                                        NaN            NaN             3
# 16          30                            NaN            NaN             2
# 17                                        NaN            NaN             3
# 0                                         NaN            NaN             3
# 1           23                            NaN            NaN             4
# 2                                         NaN            NaN             4
# 3           22                            NaN            NaN             3
# ..         ...               ...          ...            ...           ...
# 3           34               NaN          NaN            NaN           NaN
# 4           31               NaN          NaN            NaN           NaN
# 5           26               NaN          NaN            NaN           NaN
# 6                            NaN          NaN            NaN           NaN
# 7                            NaN          NaN            NaN           NaN
# 8                            NaN          NaN            NaN           NaN
# 9                            NaN          NaN            NaN           NaN
# 10                           NaN          NaN            NaN           NaN
# 0          NaN                            NaN            NaN           NaN
# 1          NaN                            NaN            NaN           NaN
# 2          NaN                            NaN            NaN           NaN
# 3          NaN                            NaN            NaN           NaN
# 4          NaN                            NaN            NaN           NaN
# 5          NaN                 6          NaN            NaN           NaN
# 6          NaN                 7          NaN            NaN           NaN
# 7          NaN                            NaN            NaN           NaN
# 8          NaN                            NaN            NaN           NaN
# 9          NaN                 5          NaN            NaN           NaN
# 10         NaN                            NaN            NaN           NaN
# 11         NaN                 6          NaN            NaN           NaN
# 0          NaN                                           NaN           NaN
# 1          NaN                 6                         NaN           NaN
# 2          NaN                              4            NaN           NaN
# 3          NaN                                           NaN           NaN
# 4          NaN               6.5                         NaN           NaN
# 5          NaN                                           NaN           NaN
# 6          NaN                                           NaN           NaN
# 7          NaN                                           NaN           NaN
# 8          NaN                 6                         NaN           NaN
# 9          NaN                 7                         NaN           NaN
#
#                       Date Emmanuel Macron François Asselineau  \
# 0     9 au 12 octobre 2012             NaN                 NaN
# 0      11 au 15 avril 2013             NaN                 NaN
# 1      16 au 17 avril 2013             NaN                 NaN
# 2      26 au 28 avril 2013             NaN                 NaN
# 3      26 au 29 avril 2013             NaN                 NaN
# 4      26 au 29 avril 2013             NaN                 NaN
# 5      26 au 29 avril 2013             NaN                 NaN
# 6          2 et 3 mai 2013             NaN                 NaN
# 0      11 au 13 avril 2014             NaN                 NaN
# 1      15 au 18 avril 2014             NaN                 NaN
# 2      15 au 18 avril 2014             NaN                 NaN
# 3      15 au 18 avril 2014             NaN                 NaN
# 4    21 au 22 juillet 2014             NaN                 NaN
# 5    21 au 22 juillet 2014             NaN                 NaN
# 6    21 au 22 juillet 2014             NaN                 NaN
# 7    3 au 4 septembre 2014             NaN                 NaN
# 8    3 au 4 septembre 2014             NaN                 NaN
# 9    3 au 4 septembre 2014             NaN                 NaN
# 10   28 au 30 octobre 2014             NaN                 NaN
# 11   28 au 30 octobre 2014             NaN                 NaN
# 12   28 au 30 octobre 2014             NaN                 NaN
# 13   28 au 30 octobre 2014             NaN                 NaN
# 14   28 au 30 octobre 2014             NaN                 NaN
# 15   28 au 30 octobre 2014             NaN                 NaN
# 16   28 au 30 octobre 2014             NaN                 NaN
# 17   28 au 30 octobre 2014             NaN                 NaN
# 0    21 au 23 janvier 2015             NaN                 NaN
# 1    21 au 23 janvier 2015             NaN                 NaN
# 2    21 au 23 janvier 2015             NaN                 NaN
# 3    21 au 23 janvier 2015             NaN                 NaN
# ..                     ...             ...                 ...
# 3    8 au 13 novembre 2016                                 NaN
# 4    8 au 13 novembre 2016              10                 NaN
# 5   16 et 17 novembre 2016              14                 NaN
# 6   16 et 17 novembre 2016              16                 NaN
# 7   16 et 17 novembre 2016              15                 NaN
# 8         25 novembre 2016              13                 NaN
# 9         27 novembre 2016              14                 NaN
# 10        27 novembre 2016              13                 NaN
# 0         28 novembre 2016              15                 NaN
# 1         28 novembre 2016              17                 NaN
# 2         28 novembre 2016                                 NaN
# 3         28 novembre 2016              13                 NaN
# 4         28 novembre 2016              15                 NaN
# 5         28 novembre 2016              16                 NaN
# 6         28 novembre 2016            17.5                 NaN
# 7   28 et 29 novembre 2016              16                 NaN
# 8   28 et 29 novembre 2016              14                 NaN
# 9   28 et 29 novembre 2016              17                 NaN
# 10  28 au 30 novembre 2016              15                 NaN
# 11  28 au 30 novembre 2016              17                 NaN
# 0     2 et 3 décembre 2016            13.5                 NaN
# 1     2 et 3 décembre 2016              16                 NaN
# 2     2 et 3 décembre 2016              16                 NaN
# 3     2 au 4 décembre 2016              14                 NaN
# 4     2 au 4 décembre 2016              19                 NaN
# 5     2 au 4 décembre 2016                                 NaN
# 6     2 au 7 décembre 2016              13                 NaN
# 7     2 au 7 décembre 2016              15                 NaN
# 8     2 au 7 décembre 2016              16                 NaN
# 9     2 au 7 décembre 2016              18                 NaN
#
#    François Bayrou François Fillon   ...    Nicolas Sarkozy  \
# 0                7             NaN   ...               29.5
# 0               10                   ...                 30
# 1               11                   ...                 28
# 2                7                   ...                 34
# 3               10                   ...                 32
# 4               13              16   ...
# 5               14                   ...
# 6               10                   ...                 29
# 0                8                   ...                 29
# 1               12                   ...                 31
# 2               10                   ...
# 3               13              22   ...
# 4               13                   ...                 25
# 5               12                   ...                 25
# 6               16                   ...                 26
# 7               14              17   ...
# 8               11                   ...
# 9               12                   ...                 25
# 10              13                   ...                 26
# 11              10                   ...
# 12                                   ...
# 13              16              18   ...
# 14              14                   ...                 26
# 15              14                   ...                 27
# 16              10                   ...
# 17              13                   ...                 27
# 0                9             NaN   ...                 23
# 1                7             NaN   ...
# 2                7             NaN   ...                 23
# 3                7             NaN   ...
# ..             ...             ...   ...                ...
# 3                                    ...
# 4                                    ...
# 5                                    ...
# 6              8.5                   ...               17.5
# 7              5.5              20   ...
# 8                6              32   ...
# 9                6              26   ...
# 10               7              26   ...
# 0                6              29   ...                NaN
# 1                               30   ...                NaN
# 2                               34   ...                NaN
# 3                6              28   ...                NaN
# 4                               29   ...                NaN
# 5                6              29   ...                NaN
# 6                               31   ...                NaN
# 7                6              30   ...                NaN
# 8                5              31   ...                NaN
# 9                5              31   ...                NaN
# 10             5.5              28   ...                NaN
# 11               6              29   ...                NaN
# 0                7            27.5   ...                NaN
# 1                8              28   ...                NaN
# 2                9              28   ...                NaN
# 3                6              24   ...                NaN
# 4                8              23   ...                NaN
# 5                               29   ...                NaN
# 6                6              26   ...                NaN
# 7                               27   ...                NaN
# 8                7              27   ...                NaN
# 9                               29   ...                NaN
#
#    Olivier Besancenot Philippe Poutou Philippe de Villiers Rama Yade  \
# 0                 NaN             1.5                  NaN       NaN
# 0                 NaN               1                  NaN       NaN
# 1                 NaN             0.5                  NaN       NaN
# 2                 NaN               1                  NaN       NaN
# 3                 NaN               1                  NaN       NaN
# 4                 NaN               1                  NaN       NaN
# 5                 NaN               1                  NaN       NaN
# 6                 NaN               1                  NaN       NaN
# 0                 NaN               2                  NaN       NaN
# 1                 NaN             1.5                  NaN       NaN
# 2                 NaN             1.5                  NaN       NaN
# 3                 NaN             1.5                  NaN       NaN
# 4                 NaN               1                  NaN       NaN
# 5                 NaN               1                  NaN       NaN
# 6                 NaN               1                  NaN       NaN
# 7                 NaN               1                  NaN       NaN
# 8                 NaN               1                  NaN       NaN
# 9                 NaN               1                  NaN       NaN
# 10                NaN             1.5                  NaN       NaN
# 11                NaN             1.5                  NaN       NaN
# 12                NaN             1.5                  NaN       NaN
# 13                NaN             1.5                  NaN       NaN
# 14                NaN             1.5                  NaN       NaN
# 15                NaN             1.5                  NaN       NaN
# 16                NaN             1.5                  NaN       NaN
# 17                NaN             1.5                  NaN       NaN
# 0                                   2                            NaN
# 1                                   2                            NaN
# 2                                   1                            NaN
# 3                                 1.5                            NaN
# ..                ...             ...                  ...       ...
# 3                 NaN             1.5                  NaN       NaN
# 4                 NaN             1.5                  NaN       NaN
# 5                 NaN             1.5                  NaN       NaN
# 6                 NaN             1.5                  NaN       NaN
# 7                 NaN             1.5                  NaN       NaN
# 8                 NaN               1                  NaN       NaN
# 9                 NaN               1                  NaN       NaN
# 10                NaN               1                  NaN       NaN
# 0                 NaN               1                  NaN       NaN
# 1                 NaN               1                  NaN       NaN
# 2                 NaN             1.5                  NaN       NaN
# 3                 NaN               1                  NaN       NaN
# 4                 NaN               1                  NaN       NaN
# 5                 NaN               1                  NaN       NaN
# 6                 NaN               1                  NaN       NaN
# 7                 NaN               1                  NaN       NaN
# 8                 NaN               1                  NaN       NaN
# 9                 NaN               1                  NaN       NaN
# 10                NaN               1                  NaN       NaN
# 11                NaN               1                  NaN       NaN
# 0                 NaN               1                  NaN       NaN
# 1                 NaN               1                  NaN       NaN
# 2                 NaN               1                  NaN       NaN
# 3                 NaN             0.5                  NaN       NaN
# 4                 NaN               1                  NaN       NaN
# 5                 NaN               1                  NaN       NaN
# 6                 NaN               1                  NaN       NaN
# 7                 NaN               1                  NaN       NaN
# 8                 NaN               1                  NaN       NaN
# 9                 NaN               1                  NaN       NaN
#
#                        Sondeur Sylvia Pinel Yannick Jadot Échantillon Éva Joly
# 0                         Ifop          NaN           NaN       1 607        2
# 0                         Ifop          NaN           NaN       1 967      1.5
# 1                   OpinionWay          NaN           NaN       1 022        3
# 2                          CSA          NaN           NaN       1 027        2
# 3        Future Thinking - SSI          NaN           NaN       1 000        2
# 4        Future Thinking - SSI          NaN           NaN       1 000        2
# 5        Future Thinking - SSI          NaN           NaN       1 000        2
# 6                          BVA          NaN           NaN       1 086        2
# 0                  Opinion Way          NaN           NaN       1 023        2
# 1                         Ifop          NaN           NaN         998        3
# 2                         Ifop          NaN           NaN         998        3
# 3                         Ifop          NaN           NaN         998        3
# 4                         Ifop          NaN           NaN         947
# 5                         Ifop          NaN           NaN         947
# 6                         Ifop          NaN           NaN         947
# 7                         Ifop          NaN           NaN         994
# 8                         Ifop          NaN           NaN         994
# 9                         Ifop          NaN           NaN         994
# 10                        Ifop          NaN           NaN       1 382
# 11                        Ifop          NaN           NaN       1 382
# 12                        Ifop          NaN           NaN       1 382
# 13                        Ifop          NaN           NaN       1 382
# 14                        Ifop          NaN           NaN       1 382
# 15                        Ifop          NaN           NaN       1 382
# 16                        Ifop          NaN           NaN       1 382
# 17                        Ifop          NaN           NaN       1 382
# 0                         Ifop          NaN           NaN       1 051      NaN
# 1                         Ifop          NaN           NaN       1 051      NaN
# 2                         Ifop          NaN           NaN       1 051      NaN
# 3                         Ifop          NaN           NaN       1 051      NaN
# ..                         ...          ...           ...         ...      ...
# 3   Cevipof Ipsos-Sopra Steria          NaN             4      18 200      NaN
# 4   Cevipof Ipsos-Sopra Steria          NaN             3      18 200      NaN
# 5                Ifop-Fiducial          NaN           2.5         979      NaN
# 6                Ifop-Fiducial          NaN           2.5         979      NaN
# 7                Ifop-Fiducial          NaN             3         979      NaN
# 8                        Odoxa          NaN             2         844      NaN
# 9                       Harris          NaN             3        6093      NaN
# 10                      Harris          NaN             2        6093      NaN
# 0     Kantar Sofres - OnePoint            1             2        1011      NaN
# 1     Kantar Sofres - OnePoint            1             2        1011      NaN
# 2     Kantar Sofres - OnePoint            1             3        1011      NaN
# 3     Kantar Sofres - OnePoint          0.5             2        1011      NaN
# 4     Kantar Sofres - OnePoint          0.5           2.5        1011      NaN
# 5     Kantar Sofres - OnePoint            1           1.5        1011      NaN
# 6     Kantar Sofres - OnePoint            1             2        1011      NaN
# 7                        Elabe                        1.5        1000      NaN
# 8                        Elabe                        1.5        1000      NaN
# 9                        Elabe                        1.5        1000      NaN
# 10               Ifop-Fiducial          0.5             2        1882      NaN
# 11               Ifop-Fiducial            1           1.5        1882      NaN
# 0                Ifop-Fiducial            0             2        1401      NaN
# 1                Ifop-Fiducial          0.5           1.5        1401      NaN
# 2                Ifop-Fiducial            0           1.5        1401      NaN
# 3                          BVA          0.5             2         934      NaN
# 4                          BVA          0.5             2         934      NaN
# 5                          BVA          0.5           2.5         934      NaN
# 6   Cevipof Ipsos-Sopra Steria          0.5           2.5       18013      NaN
# 7   Cevipof Ipsos-Sopra Steria          0.5           2.5       18013      NaN
# 8   Cevipof Ipsos-Sopra Steria          0.5           2.5       18013      NaN
# 9   Cevipof Ipsos-Sopra Steria          0.5           2.5       18013      NaN
#
# [230 rows x 31 columns]

# %%
import datetime
plotTable(dfF3[(dfF3["Date"] > datetime.date(2016,5,25)) & (dfF3["Date"] < datetime.date(2016,12,17))])

# %%
dfF, dfFs = loadPandas(URL)
path = "C:\\Users\\Mohamed\\MS BGD\\fil_rouge_lepoint\\Sondages\\2eTour\\"
dfFs2 = dfFs
dfFs2["Date"] = dfFs2["Date"].map(lambda x : x if len(x)>5 else np.nan)
dfFs2 = dfFs2[dfFs2["Date"].notnull()]
dfFs2["Date"] = dfFs2["Date"].map(lambda x : x.replace("-", " ").replace("–", " "))
dfFs2["Date"] = dfFs2["Date"].map(lambda x : x if len(x.split(" ")) < 4 else " ".join(x.split(" ")[2:]))
dfFs2["Date"] = dfFs2["Date"].map(lambda x : dateparser.parse(x).date())
dfFs2 = dfFs2.sort_values('Date', ascending=1)

notCandidats = ["Date", "Sondeur", "Échantillon"]

def dateToString(date):
    if len(str(date.month))==1:
        month = "0"+str(date.month)
    else : 
        month = str(date.month)
        
    if len(str(date.day))==1:
        day = "0"+str(date.day)
    else : 
        day = str(date.day)
    return day+"/"+month+"/"+str(date.year)


def getDuel(df, nom1, nom2):
    return df[[nom1, nom2, "date", "Abstention, blanc ou nul"]].set_index("date").dropna(axis=0, how='any')

for col in dfFs2.columns:
    if col not in notCandidats: 
        dfFs2[col] = dfFs2[col].map(lambda x: x if isinstance(x, float) else np.nan)
        if col != "Abstention, blanc ou nul":
            dfFs2[col] = dfFs2[col]*(100-dfFs2["Abstention, blanc ou nul"])/100

dfFs2["date"] = dfFs2["Date"].map(lambda x: dateToString(x))
dfFs2 = dfFs2.drop("Date", axis=1)


getDuel(dfFs2, "Marine Le Pen", "François Fillon").to_csv(path+"mlpVSff.tsv", sep="\t", encoding="utf-8")
getDuel(dfFs2, "Marine Le Pen", "Manuel Valls").to_csv(path+"mlpVSmv.tsv", sep="\t")
getDuel(dfFs2, "Marine Le Pen", "Emmanuel Macron").to_csv(path+"mlpVSem.tsv", sep="\t")

dfFs2.to_csv(path+"sondages2e.csv")

# %%
from itertools import cycle, islice

#dfF3["Date"] = dfF3["Date"].map(lambda x : dateparser.parse(x).date())
dfFs2[(dfFs2["Marine Le Pen"].notnull()) & (dfFs2["François Fillon"].notnull()) ]
temp = dfFs2[(dfFs2["Marine Le Pen"].notnull()) & (dfFs2["François Fillon"].notnull())]
df2 = temp[["Marine Le Pen", "François Fillon", "Date"]].set_index("Date")

my_colors = list(islice(cycle(['aquamarine', 'b']), None, len(df2)))

# Specify this list of colors as the `color` option to `plot`.
ax = df2.plot(kind='barh', stacked=True, color=my_colors, title="Intentions de vote au second tour MLP vs FF", legend = False, grid = True)
ax.get_figure().savefig('2nd_tour_v0.png')
