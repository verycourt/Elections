# %%
import os
import pandas as pd
from datetime import datetime

def save_metrics(df, timestamp):
    path = 'metric_data/'
    # sauvegarde des colonnes du dataframe dans les différents .json
    for metric in df:
        try:
            current_df = pd.read_json(path + metric + '.json', orient='split')
            
            if timestamp in current_df:
                print('Fichier json deja a jour pour', metric)
                continue
                
            current_df = pd.concat([current_df, df[metric]], axis=1)
            
        except ValueError: # si le fichier n'existe pas
            current_df = pd.DataFrame(df[metric], columns=[metric], index=[df.index])

        current_df.rename(columns={metric:timestamp}, inplace=True)
        current_df.fillna(value='-', inplace=True)
        current_df.to_json(path + metric + '.json', orient='split')
        print('Data saved as ' + path + metric + '.json')
        
    return

# %%
folder = 'data/'
for tex, subdir, files in os.walk(folder):
    for file in files:
        print(tex, subdir, file)
        save_metrics(pd.read_json(folder + file, orient='split'),
                     timestamp=datetime.strptime(file[:-5], '%Y-%m-%d'))
# Out:
# data/ [] 2017-02-14.json
# Fichier json deja a jour pour 0_tw_followers
# Data saved as metric_data/1_tw_tweets.json
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Data saved as metric_data/4_yt_likes_rate.json
# Data saved as metric_data/5_yt_dislikes_rate.json
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-02-15.json
# Fichier json deja a jour pour 0_tw_followers
# Data saved as metric_data/1_tw_tweets.json
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Data saved as metric_data/4_yt_likes_rate.json
# Data saved as metric_data/5_yt_dislikes_rate.json
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-02-16.json
# Fichier json deja a jour pour 0_tw_followers
# Data saved as metric_data/1_tw_tweets.json
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Fichier json deja a jour pour 4_yt_reaction_rate
# Fichier json deja a jour pour 5_yt_satisfaction_rate
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-02-17.json
# Fichier json deja a jour pour 0_tw_followers
# Data saved as metric_data/1_tw_tweets.json
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Fichier json deja a jour pour 4_yt_reaction_rate
# Fichier json deja a jour pour 5_yt_satisfaction_rate
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-02-18.json
# Fichier json deja a jour pour 0_tw_followers
# Data saved as metric_data/1_tw_tweets.json
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Fichier json deja a jour pour 4_yt_reaction_rate
# Fichier json deja a jour pour 5_yt_satisfaction_rate
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-02-19.json
# Fichier json deja a jour pour 0_tw_followers
# Data saved as metric_data/1_tw_tweets.json
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Fichier json deja a jour pour 4_yt_reaction_rate
# Fichier json deja a jour pour 5_yt_satisfaction_rate
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-02-20.json
# Fichier json deja a jour pour 0_tw_followers
# Data saved as metric_data/1_tw_tweets.json
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Fichier json deja a jour pour 4_yt_reaction_rate
# Fichier json deja a jour pour 5_yt_satisfaction_rate
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-02-21.json
# Fichier json deja a jour pour 0_tw_followers
# Data saved as metric_data/1_tw_tweets.json
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Fichier json deja a jour pour 4_yt_reaction_rate
# Fichier json deja a jour pour 5_yt_satisfaction_rate
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-02-22.json
# Fichier json deja a jour pour 0_tw_followers
# Data saved as metric_data/1_tw_tweets.json
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Fichier json deja a jour pour 4_yt_reaction_rate
# Fichier json deja a jour pour 5_yt_satisfaction_rate
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-02-23.json
# Fichier json deja a jour pour 0_tw_followers
# Data saved as metric_data/1_tw_tweets.json
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Fichier json deja a jour pour 4_yt_reaction_rate
# Fichier json deja a jour pour 5_yt_satisfaction_rate
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-02-24.json
# Fichier json deja a jour pour 0_tw_followers
# Fichier json deja a jour pour 1_tw_mentions
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Fichier json deja a jour pour 4_yt_reaction_rate
# Fichier json deja a jour pour 5_yt_satisfaction_rate
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-02-25.json
# Fichier json deja a jour pour 0_tw_followers
# Fichier json deja a jour pour 1_tw_mentions
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Fichier json deja a jour pour 4_yt_reaction_rate
# Fichier json deja a jour pour 5_yt_satisfaction_rate
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-02-26.json
# Fichier json deja a jour pour 0_tw_followers
# Fichier json deja a jour pour 1_tw_mentions
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Fichier json deja a jour pour 4_yt_reaction_rate
# Fichier json deja a jour pour 5_yt_satisfaction_rate
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-02-27.json
# Fichier json deja a jour pour 0_tw_followers
# Fichier json deja a jour pour 1_tw_mentions
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Fichier json deja a jour pour 4_yt_reaction_rate
# Fichier json deja a jour pour 5_yt_satisfaction_rate
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-02-28.json
# Fichier json deja a jour pour 0_tw_followers
# Fichier json deja a jour pour 1_tw_mentions
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Fichier json deja a jour pour 4_yt_reaction_rate
# Fichier json deja a jour pour 5_yt_satisfaction_rate
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-03-01.json
# Fichier json deja a jour pour 0_tw_followers
# Fichier json deja a jour pour 1_tw_mentions
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Fichier json deja a jour pour 4_yt_reaction_rate
# Fichier json deja a jour pour 5_yt_satisfaction_rate
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-03-02.json
# Fichier json deja a jour pour 0_tw_followers
# Fichier json deja a jour pour 1_tw_mentions
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Fichier json deja a jour pour 4_yt_reaction_rate
# Fichier json deja a jour pour 5_yt_satisfaction_rate
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-03-03.json
# Fichier json deja a jour pour 0_tw_followers
# Fichier json deja a jour pour 1_tw_mentions
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Fichier json deja a jour pour 4_yt_reaction_rate
# Fichier json deja a jour pour 5_yt_satisfaction_rate
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-03-04.json
# Fichier json deja a jour pour 0_tw_followers
# Fichier json deja a jour pour 1_tw_mentions
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Fichier json deja a jour pour 4_yt_reaction_rate
# Fichier json deja a jour pour 5_yt_satisfaction_rate
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-03-05.json
# Fichier json deja a jour pour 0_tw_followers
# Fichier json deja a jour pour 1_tw_mentions
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Fichier json deja a jour pour 4_yt_reaction_rate
# Fichier json deja a jour pour 5_yt_satisfaction_rate
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-03-06.json
# Fichier json deja a jour pour 0_tw_followers
# Fichier json deja a jour pour 1_tw_mentions
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Fichier json deja a jour pour 4_yt_reaction_rate
# Fichier json deja a jour pour 5_yt_satisfaction_rate
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-03-07.json
# Fichier json deja a jour pour 0_tw_followers
# Fichier json deja a jour pour 1_tw_mentions
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Fichier json deja a jour pour 4_yt_reaction_rate
# Fichier json deja a jour pour 5_yt_satisfaction_rate
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-03-08.json
# Fichier json deja a jour pour 0_tw_followers
# Fichier json deja a jour pour 1_tw_mentions
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Fichier json deja a jour pour 4_yt_reaction_rate
# Fichier json deja a jour pour 5_yt_satisfaction_rate
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-03-09.json
# Fichier json deja a jour pour 0_tw_followers
# Fichier json deja a jour pour 1_tw_mentions
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Fichier json deja a jour pour 4_yt_reaction_rate
# Fichier json deja a jour pour 5_yt_satisfaction_rate
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-03-10.json
# Fichier json deja a jour pour 0_tw_followers
# Fichier json deja a jour pour 1_tw_mentions
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Fichier json deja a jour pour 4_yt_reaction_rate
# Fichier json deja a jour pour 5_yt_satisfaction_rate
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-03-11.json
# Fichier json deja a jour pour 0_tw_followers
# Fichier json deja a jour pour 1_tw_mentions
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Fichier json deja a jour pour 4_yt_reaction_rate
# Fichier json deja a jour pour 5_yt_satisfaction_rate
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-03-12.json
# Fichier json deja a jour pour 0_tw_followers
# Fichier json deja a jour pour 1_tw_mentions
# Fichier json deja a jour pour 2_yt_subscribers
# Fichier json deja a jour pour 3_yt_views_avg
# Fichier json deja a jour pour 4_yt_reaction_rate
# Fichier json deja a jour pour 5_yt_satisfaction_rate
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-03-13.json
# Fichier json deja a jour pour 0_tw_followers
# Fichier json deja a jour pour 1_tw_mentions
# Fichier json deja a jour pour 2_yt_subscribers
# Data saved as metric_data/3_yt_like_count.json
# Fichier json deja a jour pour 6_fb_likes
# Fichier json deja a jour pour 7_fb_talking_about
# data/ [] 2017-03-14.json
# Data saved as metric_data/0_tw_followers.json
# Data saved as metric_data/1_tw_mentions.json
# Data saved as metric_data/2_yt_subscribers.json
# Data saved as metric_data/3_yt_like_count.json
# Data saved as metric_data/6_fb_likes.json
# Data saved as metric_data/7_fb_talking_about.json

# %%
candidats = ['Fillon', 'Hamon', 'Le Pen', 'Macron', 'Melenchon']
folder = 'metric_data/'
for tex, subdir, files in os.walk(folder):
    for file in files:
        print(tex + file)
        a = pd.read_json(folder + file, orient='split')
        a.filter(candidats, axis=0).to_json(folder + file, orient='split')
# Out:
# metric_data/0_tw_followers.json
# metric_data/1_tw_mentions.json
# metric_data/1_tw_tweets.json
# metric_data/2_yt_subscribers.json
# metric_data/3_yt_like_count.json
# metric_data/3_yt_views_avg.json
# metric_data/4_yt_likes_rate.json
# metric_data/4_yt_reaction_rate.json
# metric_data/5_yt_dislikes_rate.json
# metric_data/5_yt_satisfaction_rate.json
# metric_data/6_fb_likes.json
# metric_data/7_fb_talking_about.json

# %%
b = pd.read_json('metric_data/0_tw_followers.json', orient='split')
b
# Out:
#            2017-02-14  2017-02-15  2017-02-16  2017-02-17  2017-02-18  \
# Fillon         423181      424011      425149      426014      426789
# Hamon          326739      327730      328988      329775      330478
# Le Pen        1272977     1274053     1275497     1276784     1278058
# Macron          57998      496473      499164      501489      503556
# Mélenchon      964205      965153      966236      967289      968269
#
#            2017-02-19  2017-02-20  2017-02-21  2017-02-22  2017-02-23  \
# Fillon         427675      428638      429347      430143      430835
# Hamon          331323      331974      332387      332865      333374
# Le Pen        1279544     1281410     1284466     1287438     1289158
# Macron         505678      508232      510271      513332      515402
# Mélenchon      969236      970551      971523      972501      973566
#
#               ...      2017-03-05  2017-03-06  2017-03-07  2017-03-08  \
# Fillon        ...          445218      447365      448673      449698
# Hamon         ...          338944      339670      340218      340815
# Le Pen        ...         1309959     1312222     1313884     1315306
# Macron        ...          539827      542253      544300      546901
# Mélenchon     ...          984215      985415      986502      987424
#
#            2017-03-09  2017-03-10  2017-03-11  2017-03-12  2017-03-13  \
# Fillon         450722      451641      452544      453580      454327
# Hamon          341421      342218      342576      342768      342946
# Le Pen        1316938     1318486     1319819     1321599     1323344
# Macron         549529      551699      553740      556027      558547
# Mélenchon      988388      989204      990033      991081      991975
#
#            2017-03-14
# Fillon         455009
# Hamon          343235
# Le Pen        1324596
# Macron         560401
# Mélenchon      992721
#
# [5 rows x 29 columns]
