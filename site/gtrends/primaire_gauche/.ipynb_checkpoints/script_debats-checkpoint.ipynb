# %%
import pandas as pd
df_w = pd.read_excel('debats_gauche_7d.xlsx')
df_m = pd.read_excel('debats_gauche_1m.xlsx')
df_w.set_index('Date', inplace=True)
df_m.set_index('Date', inplace=True)
df_w[1::2].to_json('debats_gauche_7d.json', orient='split')
df_m.to_json('debats_gauche_1m.json', orient='split')

# %%
df_w
# Out:
#                      Jean-Luc Bennahmias  Benoît Hamon  Arnaud Montebourg  \
# Date
# 2017-01-12 00:00:00                    0             2                  1
# 2017-01-12 01:00:00                    0             2                  1
# 2017-01-12 02:00:00                    0             2                  1
# 2017-01-12 03:00:00                    0             1                  2
# 2017-01-12 04:00:00                    0             2                  1
# 2017-01-12 05:00:00                    0             2                  1
# 2017-01-12 06:00:00                    0             1                  1
# 2017-01-12 07:00:00                    0             1                  1
# 2017-01-12 08:00:00                    1             1                  1
# 2017-01-12 09:00:00                    0             2                  1
# 2017-01-12 10:00:00                    0             2                  1
# 2017-01-12 11:00:00                    0             1                  1
# ...
