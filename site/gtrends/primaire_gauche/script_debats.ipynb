# %%
import pandas as pd
df_m = pd.read_excel('csv/bilan_debats.xlsx')
df_m.set_index('Jour', inplace=True)
df_m.to_json('csv/bilan_debats.json', orient='split')

# %%
df_m
# Out:
#             Jean-Luc Bennahmias  Benoît Hamon  Arnaud Montebourg  \
# Jour
# 8 janvier                     0             9                  7
# 9 janvier                     1             6                  5
# 10 janvier                    0             6                  5
# 11 janvier                    1             5                  4
# 12 janvier                   25            13                 14
# 13 janvier                   12            10                 11
# 14 janvier                    3             6                  5
# 15 janvier                   13            15                 15
# 16 janvier                    7            10                 10
# 17 janvier                    5             6                  5
# 18 janvier                    2             7                  5
# 19 janvier                   12            18                 15
# 20 janvier                    4            12                  9
#
# ...
