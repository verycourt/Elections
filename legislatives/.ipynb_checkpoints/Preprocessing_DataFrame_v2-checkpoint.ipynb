# %% [markdown]
# #### To do
# Analyse des données manquantes :
# - etrangers : Français de l'étranger => moyenne des étrangers ailleurs ?
# - part des ménages imposés et quartiles de revenu : Français de l'étranger et DOM (à part Réunion et Martinique) => utiliser les données de la Réunion et de la Martinique pour les autres DOM ? et moyenne nationale pour les français de l'étranger ?
# - chômage : Français de l'étranger => utiliser moyenne nationale ?
# - diplômes et CSP : Français de l'étranger, petits DOM (Wallis et Futuna, Nouvelle Calédonie, etc...) => utiliser moyenne des autres DOM ? et moyenne nationale pour les français de l'étranger ?
#
# Nouvelles features :
# - Données géo par Dept (dummy sur position Littoral, métropole, péri-urbain à établir par la densité de pop, est-ouest, Nord-Sud)

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import Imputer, StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# #### Retrait des colonnes et lignes inutiles / sélection de features

# %%
# load data
raw = pd.read_excel('data/dataframe_elections.xlsx')
print('Taille initiale du DF :', raw.shape)

# drop lignes
raw = raw[raw['an'] > 1997]

# Données d'identification
id_list = ['an', 'code', 'nom', 'prenom', 'nuance_groupe', 'second_tour']
df_id = raw[id_list]

# drop colonnes
drop_list = ['c_dep', 'dep', 'circo', 'code', 'inscrits', 'circo_parti', 'circo_nuance',
             'nom', 'prenom', 'etiquette', 'nuance', 'voix', 'second_tour']
raw = raw.drop(drop_list, axis=1)

print('Taille du DF après retrait de 1997 et des colonnes inutiles :', raw.shape)
# Out:
# Taille initiale du DF : (36919, 75)
# Taille du DF après retrait de 1997 et des colonnes inutiles : (30565, 62)

# %% [markdown]
# ### Feature engineering

# %% [markdown]
# #### Retrait des features qui dégradent le modèle

# %%
keep_list = ['an', 'p_voix'] # à garder obligatoirement pour identifier les lignes et créer les labels
keep_list.extend([#'geo_frontalier', 'geo_dom', 'geo_idf',
                  'part_impose', 'chom_tot',
                  #'p_agri', 'p_ouvriers', 'd_brevet','d_sup',
                  'circo_leg_meme_nuance', 'circo_meme_nuance_president', 'circo_pres_meme_nuance',
                  'nb_candidats_meme_bloc', 'score_nuance_groupe_pres', 'score_candidat_prec_leg',
                  #'score_nuance_groupe_prec_leg', #(un peu mauvais)
                  #'score_bloc_pres', 'score_bloc_prec_leg', #(mauvais pour le score)
                  #'nuance_groupe',
                  'taux_vote_pres', 'taux_vote_leg',
                  'depute_sortant', 'ancien_depute', 'au_gouvernement', 'ancien_ministre',
                  'sexe'
    ])

df = raw.drop([col for col in raw.columns if col not in keep_list], axis=1)

# %%
print(df.columns)
# Out:
# Index(['an', 'part_impose', 'chom_tot', 'circo_leg_meme_nuance',
#        'nb_candidats_meme_bloc', 'taux_vote_leg', 'circo_pres_meme_nuance',
#        'circo_meme_nuance_president', 'score_nuance_groupe_pres',
#        'taux_vote_pres', 'score_candidat_prec_leg', 'depute_sortant',
#        'ancien_depute', 'au_gouvernement', 'ancien_ministre', 'sexe',
#        'p_voix'],
#       dtype='object')

# %% [markdown]
# #### Gestion des NaN

# %%
# Score du candidat aux législatives précédentes
df['score_candidat_prec_leg'] = df['score_candidat_prec_leg'].fillna(.1)
# remplacer les données par une moyenne du parti
# TODO ...

# Catégorisation
# df['score_candidat_prec_leg'] = pd.cut(df['score_candidat_prec_leg'], bins=[-1, -.01, .05, .1, .15, .2, 1],
#                                       labels=['N/A', 'A', 'B', 'C', 'D', 'E'])

# raw['score_candidat_prec_leg'] = raw['score_candidat_prec_leg'].fillna(value=raw['score_candidat_prec_leg'].mean())

# %%
print(df.shape)
print(df.isnull().sum())
# Out:
# (30565, 17)
# an                                0
# part_impose                    1089
# chom_tot                        360
# circo_leg_meme_nuance             0
# nb_candidats_meme_bloc            0
# taux_vote_leg                   185
# circo_pres_meme_nuance            0
# circo_meme_nuance_president       0
# score_nuance_groupe_pres          0
# taux_vote_pres                    0
# score_candidat_prec_leg           0
# depute_sortant                    0
# ancien_depute                     0
# au_gouvernement                   0
# ancien_ministre                   0
# sexe                              0
# p_voix                         7881
# dtype: int64

# %% [markdown]
# #### Création des ensembles de train/validation/test

# %%
def train_val_splits(df, year_for_validation):
    df_train = df[(df.an != 2017) & (df.an != year_for_validation)].dropna(how='any')
    y_train = df_train.p_voix
    X_train = df_train.drop(['an', 'p_voix'], axis=1)
    
    df_val = df[df.an == year_for_validation].dropna(how='any')
    y_val = df_val.p_voix
    X_val = df_val.drop(['an', 'p_voix'], axis=1)
    
    return X_train, X_val, y_train, y_val

# %%
# Liste des variables dummies et binaires pour les exclure de la normalisation
dummies_list = ['bloc', 'an', 'p_voix', 'sexe',
                #'geo_frontalier', 'geo_dom', 'geo_idf',
                'circo_nuance_groupe', 'circo_bloc', 'nuance_groupe',
                'circo_nuance_groupe_pres', 'circo_pres_meme_nuance', 'circo_meme_nuance_president',
                'circo_leg_meme_nuance',
                'depute_sortant', 'ancien_depute', 'au_gouvernement', 'ancien_ministre',
                'nb_candidats_meme_bloc', 'score_candidat_prec_leg']
scale_list = [col for col in df.columns if col not in dummies_list]
print(scale_list)

df_dummified = pd.get_dummies(df, drop_first=True)
X_train, X_val, y_train, y_val = train_val_splits(df_dummified, 2012)

# Normalisation du dataframe
scaler = StandardScaler()
X_train[scale_list] = scaler.fit_transform(X_train[scale_list])
X_val[scale_list] = scaler.transform(X_val[scale_list])

print(X_train.shape, X_val.shape)
print(y_train.shape, y_val.shape)
# Out:
# ['part_impose', 'chom_tot', 'taux_vote_leg', 'score_nuance_groupe_pres', 'taux_vote_pres']
# (15704, 15) (6276, 15)
# (15704,) (6276,)

# %% [markdown]
# #### Exploration

# %%
X_train.head(5)
# Out:
#        part_impose  chom_tot  circo_leg_meme_nuance  nb_candidats_meme_bloc  \
# 14488     0.135974 -1.195229                    0.0                     3.0
# 14489     0.135974 -1.195229                    1.0                     2.0
# 14490     0.135974 -1.195229                    0.0                     1.0
# 14491     0.135974 -1.195229                    0.0                     3.0
# 14492     0.135974 -1.195229                    0.0                     3.0
#
#        taux_vote_leg  circo_pres_meme_nuance  circo_meme_nuance_president  \
# 14488      -0.428999                     0.0                          0.0
# 14489      -0.428999                     1.0                          1.0
# 14490      -0.428999                     0.0                          0.0
# 14491      -0.428999                     0.0                          0.0
# 14492      -0.428999                     0.0                          0.0
#
#        score_nuance_groupe_pres  taux_vote_pres  score_candidat_prec_leg  \
# 14488                 -0.714429        1.205046                      0.1
# 14489                  3.426466        1.205046                      0.1
# 14490                  0.530380        1.205046                      0.1
# 14491                  2.039692        1.205046                      0.1
# 14492                 -0.494757        1.205046                      0.1
#
#        depute_sortant  ancien_depute  au_gouvernement  ancien_ministre  sexe_M
# 14488             0.0            0.0              0.0              0.0       1
# 14489             0.0            0.0              0.0              0.0       1
# 14490             0.0            0.0              0.0              0.0       0
# 14491             0.0            0.0              0.0              0.0       1
# 14492             0.0            0.0              0.0              0.0       0

# %%
X_val.head(5)
# Out:
#       part_impose  chom_tot  circo_leg_meme_nuance  nb_candidats_meme_bloc  \
# 7881     0.121356 -0.797027                    0.0                     3.0
# 7882     0.121356 -0.797027                    0.0                     3.0
# 7883     0.121356 -0.797027                    0.0                     3.0
# 7884     0.121356 -0.797027                    1.0                     3.0
# 7885     0.121356 -0.797027                    0.0                     3.0
#
#       taux_vote_leg  circo_pres_meme_nuance  circo_meme_nuance_president  \
# 7881      -1.263185                     0.0                          0.0
# 7882      -1.263185                     0.0                          0.0
# 7883      -1.263185                     0.0                          0.0
# 7884      -1.263185                     1.0                          0.0
# 7885      -1.263185                     0.0                          0.0
#
#       score_nuance_groupe_pres  taux_vote_pres  score_candidat_prec_leg  \
# 7881                 -0.638216        0.692942                   0.1000
# 7882                 -0.881798        0.692942                   0.0019
# 7883                  0.259899        0.692942                   0.1000
# 7884                  2.682271        0.692942                   0.2799
# 7885                  2.083029        0.692942                   0.1895
#
#       depute_sortant  ancien_depute  au_gouvernement  ancien_ministre  sexe_M
# 7881             0.0            0.0              0.0              0.0       0
# 7882             0.0            0.0              0.0              0.0       1
# 7883             0.0            0.0              0.0              0.0       1
# 7884             1.0            1.0              0.0              0.0       1
# 7885             0.0            0.0              0.0              0.0       1

# %%
# imp = Imputer(missing_values='NaN', strategy='mean', axis=0)
# imp = imp.fit(X_train)# Impute our data, then train
# X_train_imp = imp.transform(X_train)

# %%
# imp = Imputer(missing_values='NaN', strategy='mean', axis=0)
# imp = imp.fit(X_test)# Impute our data, then train
# X_test_imp = imp.transform(X_test)

# %%
rf = RandomForestRegressor(n_jobs=-1, n_estimators=150)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_val)

# %% [markdown]
# ### Analyser les prédictions

# %%
def get_predictions(y_pred, y_val, id_val):
    res = pd.concat([id_val, pd.DataFrame(y_val)], axis=1, join='inner')
    res['prediction'] = y_pred
    res['ecart'] = y_pred - res['p_voix']
    return res

# %%
df_predictions = get_predictions(y_pred, y_val, df_id)
n = df_predictions.shape[0]
print('Prédictions pour {} candidats.'.format(n))
# Out:
# Prédictions pour 6276 candidats.

# %%
sorted(list(zip(rf.feature_importances_*100, X_train.columns)), reverse=True)
# Out:
# [(51.749415029772827, 'score_candidat_prec_leg'),
#  (16.850503439748874, 'score_nuance_groupe_pres'),
#  (16.728088659630679, 'circo_meme_nuance_president'),
#  (2.812949079631196, 'nb_candidats_meme_bloc'),
#  (2.542577772584496, 'taux_vote_pres'),
#  (2.0113588486184368, 'part_impose'),
#  (2.0079697813253206, 'taux_vote_leg'),
#  (1.7247777133276649, 'depute_sortant'),
#  (1.6291612862113274, 'chom_tot'),
#  (0.79990675709372649, 'circo_leg_meme_nuance'),
#  (0.51144061795322859, 'circo_pres_meme_nuance'),
#  (0.4078075006510305, 'sexe_M'),
#  (0.18935756578717711, 'ancien_depute'),
#  (0.02756300428370707, 'ancien_ministre'),
#  (0.0071229433802843262, 'au_gouvernement')]

# %%
from sklearn.metrics import auc

ecarts_absolus = abs(df_predictions['ecart'])
max_ecart = np.max(ecarts_absolus)
grid = np.arange(max_ecart, step=.01)
ecarts_grid = []
for point in grid:
    ecarts_grid.append(np.sum(ecarts_absolus < point))

print('La MAE est : {:.2f}%'.format(mean_absolute_error(y_val, y_pred) * 100))
print('La plus grosse erreur est : {:.2f}%'.format(max_ecart * 100))
print('Le score AUC est : {:.2f}%'.format(auc(grid, ecarts_grid) * 100 / max_ecart / n))

point_list = [.01, .02, .05, .1]
ecart_list = [np.sum(ecarts_absolus < point) for point in point_list]

plt.figure(1, figsize=(13, 3))
plt.subplot(121)
plt.plot(grid, ecarts_grid)
for i in range(len(point_list)):
    plt.plot(point_list[i], ecart_list[i], 'ro')
    plt.text(point_list[i]+.005, ecart_list[i]+.005, '{:.2f}%'.format(ecart_list[i]/n))

plt.subplot(122)
plt.hist(df_predictions['ecart'] * 100, bins=50)
plt.show()
# Out:
# La MAE est : 2.13%
# La plus grosse erreur est : 27.73%
# Le score AUC est : 89.53%

# %%
df_predictions.sort_values(by='ecart').tail(5)
# Out:
#          an   code       nom         prenom nuance_groupe second_tour  p_voix  \
# 13015  2012   69|7    DEBIOL  JEAN-FRANCOIS           DVD           N  0.0290
# 8999   2012   24|2  GARRIGUE         DANIEL           DVD           N  0.0863
# 12030  2012  59|10  VANNESTE      CHRISTIAN           DVD           N  0.0612
# 10518  2012   34|3     GRAND    JEAN-PIERRE            LR           O  0.1076
# 10672  2012   35|7   CLEMENT         PASCAL            FN           N  0.0447
#
#        prediction     ecart
# 13015    0.157745  0.128745
# 8999     0.220947  0.134647
# 12030    0.226496  0.165296
# 10518    0.277195  0.169595
# 10672    0.220298  0.175598

# %%
df_predictions.sort_values(by='ecart').head(5)
# Out:
#          an   code       nom     prenom nuance_groupe second_tour  p_voix  \
# 12340  2012   75|6    DUFLOT     CECILE           ECO           O  0.2890
# 12414  2012  75|10    BAUPIN      DENIS           ECO           O  0.2502
# 13389  2012   76|2    MOINET  VERONIQUE           ECO           O  0.2138
# 9036   2012   25|2   ALAUZET       ERIC           ECO           O  0.2248
# 10882  2012   38|9  BONNETON    MICHELE           ECO           O  0.2116
#
#        prediction     ecart
# 12340    0.030618 -0.258382
# 12414    0.024332 -0.225868
# 13389    0.010603 -0.203197
# 9036     0.021841 -0.202959
# 10882    0.013875 -0.197725

# %%
df_predictions[df_predictions['nuance_groupe']=='ECO'].sort_values(by='ecart')
# Out:
#          an   code                nom           prenom nuance_groupe  \
# 12340  2012   75|6             DUFLOT           CECILE           ECO
# 12414  2012  75|10             BAUPIN            DENIS           ECO
# 13389  2012   76|2             MOINET        VERONIQUE           ECO
# 12759  2012   63|3              AUROI         DANIELLE           ECO
# 9036   2012   25|2            ALAUZET             ERIC           ECO
# 10882  2012   38|9           BONNETON          MICHELE           ECO
# 13916  2012   95|2          VUILLETET        GUILLAUME           ECO
# 10060  2012   52|1            ANDRIOT         PATRICIA           ECO
# 13644  2012   80|2            POMPILI          BARBARA           ECO
# 11696  2012   54|4           HOUCHARD      MARIE-NEIGE           ECO
# 14450  2012   78|9            SATOURI           MOUNIR           ECO
# 11220  2012   45|1              GRAND    JEAN-PHILIPPE           ECO
# 14460  2012  78|10         POURSINOFF             ANNY           ECO
# 8531   2012  13|10            LAMBERT  FRANCOIS-MICHEL           ECO
# 9670   2012   30|6             CAVARD       CHRISTOPHE           ECO
# 13310  2012   77|6              PINET         CAROLINE           ECO
# 8324   2012   67|3           BUCHMANN           ANDREE           ECO
# 11775  2012   56|4              MOLAC             PAUL           ECO
# 13212  2012   73|1             CARACO            ALAIN           ECO
# 13818  2012   94|6            ABEILLE         LAURENCE           ECO
# 12186  2012   60|4              CANON          PATRICK           ECO
# 10742  2012   37|2          ROSSIGNOL       CHRISTOPHE           ECO
# 10150  2012   74|3            SAILLET          GILBERT           ECO
# 8476   2012   13|6           SEMERIVA           PIERRE           ECO
# 9347   2012   28|4            LAANAYA            KARIM           ECO
# 8294   2012   12|3          FOULQUIER    MARIE-THERESE           ECO
# 13040  2012   69|9              MEYER          VINCENT           ECO
# 10491  2012   34|1           ROUMEGAS       JEAN-LOUIS           ECO
# 11072  2012   42|4          BENCHARIF             LELA           ECO
# 8644   2012   14|5             ATTARD         ISABELLE           ECO
# ...     ...    ...                ...              ...           ...
# 10798  2012   38|2             BOETTI           JEROME           ECO
# 13369  2012  77|11               RUBY            SERGE           ECO
# 11817  2012   57|2          HERMITANT          VINCENT           ECO
# 10521  2012   34|3            LAMOTTE          GREGORY           ECO
# 13252  2012   77|1         DESCATEAUX         SEVERINE           ECO
# 10509  2012   34|2            SCHMITT             ERIC           ECO
# 13962  2012   95|6           VERGNAUD         FREDERIC           ECO
# 9907   2012   31|1               BAUD           ROBERT           ECO
# 12162  2012   60|2            HERBAUT         AMANDINE           ECO
# 14048  2012   83|5                 BA           MOUSSA           ECO
# 10349  2012   92|4       PERRIN-BIDAN         STEPHANE           ECO
# 10345  2012   92|4               HARE     MARIE-CLAIRE           ECO
# 8679   2012   15|2           LO VERDE           CLAUDE           ECO
# 8469   2012   13|6   ESTEVE-NARSISYAN        DOMINIQUE           ECO
# 8553   2012  13|12            RAVENET           JEROME           ECO
# 12160  2012   60|2            DOURLAT         FABIENNE           ECO
# 8545   2012  13|12         AVEDISSIAN          CORINNE           ECO
# 11512  2012   51|3              BALLU         MATTHIEU           ECO
# 13309  2012   77|6       PENNACCHIONI        DOMINIQUE           ECO
# 13811  2012   94|5            GAUTIER          GREGORY           ECO
# 12203  2012   60|5            WILQUIN              LUC           ECO
# 13068  2012  69|11           KOHLHAAS     JEAN-CHARLES           ECO
# 13654  2012   80|3             TABARY           GERARD           ECO
# 13607  2012  93|12  ABOUHAMDA-MEZIANI            ELIAS           ECO
# 11106  2012   44|1              GIREL           NICOLE           ECO
# 12257  2012   75|1          BERTHAULT          GREGORY           ECO
# 12433  2012  75|11             BLAUEL            CELIA           ECO
# 12437  2012  75|11               CUSA            MIRON           ECO
# 12442  2012  75|11             MULLER    MAXIME-VALERY           ECO
# 10042  2012   43|1             COCHET         PHILIPPE           ECO
#
#       second_tour  p_voix  prediction     ecart
# 12340           O  0.2890    0.012636 -0.276364
# 12414           O  0.2502    0.015941 -0.234259
# 13389           O  0.2138    0.008195 -0.205605
# 12759           O  0.2183    0.015451 -0.202849
# 9036            O  0.2248    0.026796 -0.198004
# 10882           O  0.2116    0.015612 -0.195988
# 13916           O  0.2070    0.018339 -0.188661
# 10060           O  0.1935    0.008277 -0.185223
# 13644           O  0.1914    0.016652 -0.174748
# 11696           O  0.1888    0.017738 -0.171062
# 14450           O  0.1808    0.013519 -0.167281
# 11220           O  0.1863    0.021492 -0.164808
# 14460           O  0.2116    0.046834 -0.164766
# 8531            O  0.1720    0.015775 -0.156225
# 9670            O  0.1741    0.020438 -0.153662
# 13310           O  0.1699    0.020306 -0.149594
# 8324            O  0.1894    0.041178 -0.148222
# 11775           O  0.1580    0.010831 -0.147169
# 13212           O  0.1692    0.022502 -0.146698
# 13818           O  0.1570    0.014321 -0.142679
# 12186           O  0.1539    0.011629 -0.142271
# 10742           O  0.1520    0.014708 -0.137292
# 10150           O  0.1516    0.016299 -0.135301
# 8476            O  0.1518    0.021739 -0.130061
# 9347            N  0.1414    0.012513 -0.128887
# 8294            O  0.1410    0.015728 -0.125272
# 13040           O  0.1403    0.015555 -0.124745
# 10491           O  0.1529    0.031123 -0.121777
# 11072           O  0.1309    0.013115 -0.117785
# 8644            O  0.1281    0.012589 -0.115511
# ...           ...     ...         ...       ...
# 10798           N  0.0024    0.026878  0.024478
# 13369           N  0.0034    0.028103  0.024703
# 11817           N  0.0028    0.027563  0.024763
# 10521           N  0.0073    0.032117  0.024817
# 13252           N  0.0022    0.027386  0.025186
# 10509           N  0.0053    0.030834  0.025534
# 13962           N  0.0036    0.030065  0.026465
# 9907            N  0.0018    0.028280  0.026480
# 12162           N  0.0066    0.033323  0.026723
# 14048           N  0.0041    0.031164  0.027064
# 10349           N  0.0031    0.030306  0.027206
# 10345           N  0.0024    0.030306  0.027906
# 8679            N  0.0024    0.030601  0.028201
# 8469            N  0.0034    0.031827  0.028427
# 8553            N  0.0049    0.033508  0.028608
# 12160           N  0.0047    0.033323  0.028623
# 8545            N  0.0037    0.032512  0.028812
# 11512           N  0.0049    0.034026  0.029126
# 13309           N  0.0023    0.032869  0.030569
# 13811           N  0.0042    0.034813  0.030613
# 12203           N  0.0039    0.034787  0.030887
# 13068           N  0.0225    0.054203  0.031703
# 13654           N  0.0012    0.033182  0.031982
# 13607           N  0.0023    0.039188  0.036888
# 11106           N  0.0073    0.046608  0.039308
# 12257           N  0.0038    0.045185  0.041385
# 12433           N  0.0367    0.078973  0.042273
# 12437           N  0.0039    0.071156  0.067256
# 12442           N  0.0029    0.080093  0.077193
# 10042           N  0.0027    0.091203  0.088503
#
# [1057 rows x 9 columns]
