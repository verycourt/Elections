# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import unicodedata
from sklearn.metrics import mean_absolute_error, r2_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Scrap

# %%
url = "http://www.francetvinfo.fr/elections/resultats/"
resultats = requests.get(url)
soup = BeautifulSoup(resultats.text, 'html.parser')
df = pd.DataFrame(columns=["depart", "code", "circo", "nom", "parti", "score"])
circos_url = []

index=0


for depart in soup.find("section", {"id": "departmentResults"}).findAll("a", href=True):
    url_depart = depart["href"]
    print(url_depart)
    
    soup_depart = BeautifulSoup(requests.get(url_depart).text, 'html.parser')
    depart_name = url_depart.split("/")[-2][:-3]
    depart_number = url_depart.split("_")[-1][:-1]
    i=0
    for circo in (soup_depart.findAll("section")[3].findAll("a", href=True)):
        circo_number = i
        url_circo = circo["href"]
        
        if url_circo in circos_url:
            continue
        else : 
            circos_url.append(url_circo)
            i+=1
        
        try:
            soup_circo = BeautifulSoup(requests.get(url_circo).text, 'html.parser')
        except:
            print("error at : ", url_circo)
            continue
            
        candidats = soup_circo.findAll("section")[3].findAll("div", {"class" : re.compile("^candidate")})[:-2]
        
        for candidat in candidats: 
            try:
                name = candidat.find("span", {"class": "name"}).text
                parti = candidat.find("span", {"class": "party"}).text
                score = candidat.find("span", {"class": "percent"}).text
                df.loc[index] = [depart_name, depart_number, circo_number, name, parti, score]
                index+=1
            except :
                print("error at ", depart_name, circo_number)
                continue
# Out:
# http://www.francetvinfo.fr/elections/resultats/ain_01/
# http://www.francetvinfo.fr/elections/resultats/aisne_02/
# http://www.francetvinfo.fr/elections/resultats/allier_03/
# http://www.francetvinfo.fr/elections/resultats/alpes-de-haute-provence_04/
# http://www.francetvinfo.fr/elections/resultats/hautes-alpes_05/
# http://www.francetvinfo.fr/elections/resultats/alpes-maritimes_06/
# http://www.francetvinfo.fr/elections/resultats/ardeche_07/
# http://www.francetvinfo.fr/elections/resultats/ardennes_08/
# http://www.francetvinfo.fr/elections/resultats/ariege_09/
# http://www.francetvinfo.fr/elections/resultats/aube_10/
# http://www.francetvinfo.fr/elections/resultats/aude_11/
# http://www.francetvinfo.fr/elections/resultats/aveyron_12/
# http://www.francetvinfo.fr/elections/resultats/bouches-du-rhone_13/
# http://www.francetvinfo.fr/elections/resultats/calvados_14/
# http://www.francetvinfo.fr/elections/resultats/cantal_15/
# http://www.francetvinfo.fr/elections/resultats/charente_16/
# http://www.francetvinfo.fr/elections/resultats/charente-maritime_17/
# http://www.francetvinfo.fr/elections/resultats/cher_18/
# http://www.francetvinfo.fr/elections/resultats/correze_19/
# http://www.francetvinfo.fr/elections/resultats/cote-d-or_21/
# http://www.francetvinfo.fr/elections/resultats/cotes-d-armor_22/
# http://www.francetvinfo.fr/elections/resultats/creuse_23/
# http://www.francetvinfo.fr/elections/resultats/dordogne_24/
# http://www.francetvinfo.fr/elections/resultats/doubs_25/
# http://www.francetvinfo.fr/elections/resultats/drome_26/
# http://www.francetvinfo.fr/elections/resultats/eure_27/
# http://www.francetvinfo.fr/elections/resultats/eure-et-loir_28/
# http://www.francetvinfo.fr/elections/resultats/finistere_29/
# http://www.francetvinfo.fr/elections/resultats/corse-sud_2A/
# http://www.francetvinfo.fr/elections/resultats/haute-corse_2B/
# http://www.francetvinfo.fr/elections/resultats/gard_30/
# http://www.francetvinfo.fr/elections/resultats/haute-garonne_31/
# http://www.francetvinfo.fr/elections/resultats/gers_32/
# http://www.francetvinfo.fr/elections/resultats/gironde_33/
# http://www.francetvinfo.fr/elections/resultats/herault_34/
# http://www.francetvinfo.fr/elections/resultats/ille-et-vilaine_35/
# http://www.francetvinfo.fr/elections/resultats/indre_36/
# http://www.francetvinfo.fr/elections/resultats/indre-et-loire_37/
# http://www.francetvinfo.fr/elections/resultats/isere_38/
# http://www.francetvinfo.fr/elections/resultats/jura_39/
# http://www.francetvinfo.fr/elections/resultats/landes_40/
# http://www.francetvinfo.fr/elections/resultats/loir-et-cher_41/
# http://www.francetvinfo.fr/elections/resultats/loire_42/
# http://www.francetvinfo.fr/elections/resultats/haute-loire_43/
# http://www.francetvinfo.fr/elections/resultats/loire-atlantique_44/
# http://www.francetvinfo.fr/elections/resultats/loiret_45/
# http://www.francetvinfo.fr/elections/resultats/lot_46/
# http://www.francetvinfo.fr/elections/resultats/lot-et-garonne_47/
# http://www.francetvinfo.fr/elections/resultats/lozere_48/
# http://www.francetvinfo.fr/elections/resultats/maine-et-loire_49/
# http://www.francetvinfo.fr/elections/resultats/manche_50/
# http://www.francetvinfo.fr/elections/resultats/marne_51/
# http://www.francetvinfo.fr/elections/resultats/haute-marne_52/
# http://www.francetvinfo.fr/elections/resultats/mayenne_53/
# http://www.francetvinfo.fr/elections/resultats/meurthe-et-moselle_54/
# http://www.francetvinfo.fr/elections/resultats/meuse_55/
# http://www.francetvinfo.fr/elections/resultats/morbihan_56/
# http://www.francetvinfo.fr/elections/resultats/moselle_57/
# http://www.francetvinfo.fr/elections/resultats/nievre_58/
# http://www.francetvinfo.fr/elections/resultats/nord_59/
# http://www.francetvinfo.fr/elections/resultats/oise_60/
# http://www.francetvinfo.fr/elections/resultats/orne_61/
# http://www.francetvinfo.fr/elections/resultats/pas-de-calais_62/
# http://www.francetvinfo.fr/elections/resultats/puy-de-dome_63/
# http://www.francetvinfo.fr/elections/resultats/pyrenees-atlantiques_64/
# http://www.francetvinfo.fr/elections/resultats/hautes-pyrenees_65/
# http://www.francetvinfo.fr/elections/resultats/pyrenees-orientales_66/
# http://www.francetvinfo.fr/elections/resultats/bas-rhin_67/
# http://www.francetvinfo.fr/elections/resultats/haut-rhin_68/
# http://www.francetvinfo.fr/elections/resultats/rhone_69/
# http://www.francetvinfo.fr/elections/resultats/haute-saone_70/
# http://www.francetvinfo.fr/elections/resultats/saone-et-loire_71/
# http://www.francetvinfo.fr/elections/resultats/sarthe_72/
# http://www.francetvinfo.fr/elections/resultats/savoie_73/
# http://www.francetvinfo.fr/elections/resultats/haute-savoie_74/
# http://www.francetvinfo.fr/elections/resultats/paris_75/
# http://www.francetvinfo.fr/elections/resultats/seine-maritime_76/
# http://www.francetvinfo.fr/elections/resultats/seine-et-marne_77/
# http://www.francetvinfo.fr/elections/resultats/yvelines_78/
# http://www.francetvinfo.fr/elections/resultats/deux-sevres_79/
# http://www.francetvinfo.fr/elections/resultats/somme_80/
# http://www.francetvinfo.fr/elections/resultats/tarn_81/
# http://www.francetvinfo.fr/elections/resultats/tarn-et-garonne_82/
# http://www.francetvinfo.fr/elections/resultats/var_83/
# http://www.francetvinfo.fr/elections/resultats/vaucluse_84/
# http://www.francetvinfo.fr/elections/resultats/vendee_85/
# http://www.francetvinfo.fr/elections/resultats/vienne_86/
# http://www.francetvinfo.fr/elections/resultats/haute-vienne_87/
# http://www.francetvinfo.fr/elections/resultats/vosges_88/
# http://www.francetvinfo.fr/elections/resultats/yonne_89/
# http://www.francetvinfo.fr/elections/resultats/territoire-de-belfort_90/
# http://www.francetvinfo.fr/elections/resultats/essonne_91/
# http://www.francetvinfo.fr/elections/resultats/hauts-de-seine_92/
# http://www.francetvinfo.fr/elections/resultats/seine-saint-denis_93/
# http://www.francetvinfo.fr/elections/resultats/val-de-marne_94/
# http://www.francetvinfo.fr/elections/resultats/val-d-oise_95/
# http://www.francetvinfo.fr/elections/resultats/metropole-de-lyon_69M/
# error at :  /elections/resultats/auvergne-rhone-alpes/
# http://www.francetvinfo.fr/elections/resultats/guadeloupe_971/
# http://www.francetvinfo.fr/elections/resultats/martinique_972/
# http://www.francetvinfo.fr/elections/resultats/guyane_973/
# http://www.francetvinfo.fr/elections/resultats/la-reunion_974/
# error at :
# http://www.francetvinfo.fr/elections/resultats/saint-pierre-et-miquelon_975/
# http://www.francetvinfo.fr/elections/resultats/mayotte_976/
# http://www.francetvinfo.fr/elections/resultats/saint-martin-saint-barthelemy_977/
# http://www.francetvinfo.fr/elections/resultats/wallis-et-futuna_986/
# http://www.francetvinfo.fr/elections/resultats/polynesie-francaise_987/
# http://www.francetvinfo.fr/elections/resultats/nouvelle-caledonie_988/

# %%
df.shape
# Out:
# (7517, 6)

# %%
df2 = df.copy()

# %% [markdown]
# ## On récupère à la main certaines valeurs :

# %%
url_alamano = ["http://www.francetvinfo.fr/elections/resultats/la-reunion_974/la-reunion_1ere-circonscription",
              "http://www.francetvinfo.fr/elections/resultats/la-reunion_974/la-reunion_2eme-circonscription", 
              "http://www.francetvinfo.fr/elections/resultats/la-reunion_974/la-reunion_3eme-circonscription",
              "http://www.francetvinfo.fr/elections/resultats/la-reunion_974/la-reunion_4eme-circonscription",
              "http://www.francetvinfo.fr/elections/resultats/la-reunion_974/la-reunion_5eme-circonscription",
              "http://www.francetvinfo.fr/elections/resultats/la-reunion_974/la-reunion_6eme-circonscription",
              "http://www.francetvinfo.fr/elections/resultats/la-reunion_974/la-reunion_7eme-circonscription",
              "http://www.francetvinfo.fr/elections/resultats/guyane_973/guyane_1ere-circonscription",
              "http://www.francetvinfo.fr/elections/resultats/guyane_973/guyane_2eme-circonscription"]
for i, url in enumerate(url_alamano[-2:]):
    soup_circo = BeautifulSoup(requests.get(url).text, 'html.parser')
    for item in soup_circo.findAll("section")[3].findAll("div", {"class" : re.compile("^candidate")})[:-2]:
        name = item.find("span", {"class": "name"}).text
        parti = item.find("span", {"class": "party"}).text
        score = item.find("span", {"class": "percent"}).text
        df2.loc[df2.shape[0]+1] = ["guyane", 973, i, name, parti, score]

# %%
df2.shape
# Out:
# (7536, 6)

# %%
df2.head()
# Out:
#   depart code  circo                      nom                parti    score
# 0    ain   01    0.0           Laurent Mallet                Modem  33,89 %
# 1    ain   01    0.0            Xavier Breton     Les Républicains  26,78 %
# 2    ain   01    0.0           Jérôme Buisson       Front National  15,46 %
# 3    ain   01    0.0    Fabrine Martin Zemlik  La France insoumise   9,70 %
# 4    ain   01    0.0  Florence Blatrix-Contat     Parti socialiste   9,23 %

# %% [markdown]
# ## On gère les nom prénom

# %%
df2.score = df2.score.map(lambda x : float(x.replace(",", ".").replace("%", "").strip()))
df2.nom = df2.nom.map(lambda s : unicodedata.normalize('NFD', s).encode('ascii', 'ignore').decode("utf-8") )
df2["prenom"] = df2.nom.map(lambda x : x.split(" ")[0].upper())
df2.nom = df2.nom.map(lambda x : x.split(" ")[1].upper())
df2.circo +=1

# %%
df2.head()
# Out:
#   depart code  circo             nom                parti  score    prenom
# 0    ain   01    1.0          MALLET                Modem  33.89   LAURENT
# 1    ain   01    1.0          BRETON     Les Républicains  26.78    XAVIER
# 2    ain   01    1.0         BUISSON       Front National  15.46    JEROME
# 3    ain   01    1.0          MARTIN  La France insoumise   9.70   FABRINE
# 4    ain   01    1.0  BLATRIX-CONTAT     Parti socialiste   9.23  FLORENCE

# %% [markdown]
# ## On crée un code pour chaque circo

# %%
def f(x):
    try:
        a = float(x)
    except:
        a = x
    return a

# %%
df2.code = df2.code.map(lambda x : str(f(x))[:-2])
df2.circo = df2.circo.map(lambda x : str(x)[:-2])
df2["code_dep"] = df2.code
df2["code"] = df2[['code', 'circo']].apply(lambda x: '|'.join(x), axis=1)

# %% [markdown]
# ## Export to csv

# %%
df2.to_csv("data/resultats_1ertour.csv", index=False)

# %%
df2.head()
# Out:
#   depart code circo             nom                parti  score    prenom  \
# 0    ain  1|1     1          MALLET                Modem  33.89   LAURENT
# 1    ain  1|1     1          BRETON     Les Républicains  26.78    XAVIER
# 2    ain  1|1     1         BUISSON       Front National  15.46    JEROME
# 3    ain  1|1     1          MARTIN  La France insoumise   9.70   FABRINE
# 4    ain  1|1     1  BLATRIX-CONTAT     Parti socialiste   9.23  FLORENCE
#
#   code_dep
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %% [markdown]
# ## On récupère les pred

# %%
pred = pd.read_excel("data/predictions_du_7_6_15h35.xlsx")

# %%
pred.shape
# Out:
# (7699, 16)

# %%
pred["nom"] = pred["nom"].map(lambda x : x.split(" ")[0])

# %%
df2.merge(pred[["nom", "prenom", "code", "prediction"]], how="left", on=["nom", "prenom", "code"])
# Out:
#                    depart   code circo               nom  \
# 0                     ain    1|1     1            MALLET
# 1                     ain    1|1     1            BRETON
# 2                     ain    1|1     1           BUISSON
# 3                     ain    1|1     1            MARTIN
# 4                     ain    1|1     1    BLATRIX-CONTAT
# 5                     ain    1|1     1          FONTAINE
# 6                     ain    1|1     1          RAIMONDO
# 7                     ain    1|1     1          LEPAGNOT
# 8                     ain    1|1     1           CARLIER
# 9                     ain    1|1     1            BONNOT
# 10                    ain    1|2     2            JEANNE
# 11                    ain    1|2     2                DE
# 12                    ain    1|2     2           MICHAUD
# 13                    ain    1|2     2          THIEBAUT
# 14                    ain    1|2     2             COLIN
# 15                    ain    1|2     2           LEMERRE
# 16                    ain    1|2     2          BRULLAND
# 17                    ain    1|2     2          CHOMETTE
# 18                    ain    1|2     2          GOUTAGNY
# 19                    ain    1|2     2             SAHIN
# 20                    ain    1|3     3          GIVERNET
# 21                    ain    1|3     3            PERNOD
# 22                    ain    1|3     3            NOBLET
# 23                    ain    1|3     3             JOLIE
# 24                    ain    1|3     3           MERCIER
# 25                    ain    1|3     3  SACCHI-HASSANEIN
# 26                    ain    1|3     3             BORNE
# 27                    ain    1|3     3         SEBASTIEN
# 28                    ain    1|3     3             MOZER
# 29                    ain    1|3     3              LAHY
# ...                   ...    ...   ...               ...
# 7549  nouvelle-caledonie_  988|1     1          WENEHOUA
# 7550  nouvelle-caledonie_  988|1     1          HANOCQUE
# 7551  nouvelle-caledonie_  988|2     2             MAPOU
# 7552  nouvelle-caledonie_  988|2     2             GOMES
# 7553  nouvelle-caledonie_  988|2     2            MARTIN
# 7554  nouvelle-caledonie_  988|2     2             HENIN
# 7555  nouvelle-caledonie_  988|2     2             BRIAL
# 7556  nouvelle-caledonie_  988|2     2           VITTORI
# 7557  nouvelle-caledonie_  988|2     2        BODEOUAROU
# 7558  nouvelle-caledonie_  988|2     2              DIAZ
# 7559  nouvelle-caledonie_  988|2     2            MILLAR
# 7560               guyane  973|1     1          SERVILLE
# 7561               guyane  973|1     1     PREVOT-MADERE
# 7562               guyane  973|1     1             GUARD
# 7563               guyane  973|1     1            LETARD
# 7564               guyane  973|1     1          ALBANESI
# 7565               guyane  973|1     1           QUAMMIE
# 7566               guyane  973|1     1           ACHILLE
# 7567               guyane  973|1     1              LEON
# 7568               guyane  973|1     1           DEROCHE
# 7569               guyane  973|1     1             SABAS
# 7570               guyane  973|1     1          FEUILLIE
# 7571               guyane  973|2     2              ADAM
# 7572               guyane  973|2     2            RIMANE
# 7573               guyane  973|2     2         BERTHELOT
# 7574               guyane  973|2     2        ANTOINETTE
# 7575               guyane  973|2     2            JOIGNY
# 7576               guyane  973|2     2            RIMANE
# 7577               guyane  973|2     2           PERSDAM
# 7578               guyane  973|2     2            TADDEI
#
#                                          parti  score        prenom code_dep  \
# 0                                        Modem  33.89       LAURENT        1
# 1                             Les Républicains  26.78        XAVIER        1
# 2                               Front National  15.46        JEROME        1
# 3                          La France insoumise   9.70       FABRINE        1
# 4                             Parti socialiste   9.23      FLORENCE        1
# 5                    Parti communiste français   1.64       JACQUES        1
# 6                                   Ecologiste   1.41       LAURANE        1
# 7                               Extrême gauche   0.73         MAUDE        1
# 8                                       Divers   0.62         MARIE        1
# 9                                       Divers   0.53       GILBERT        1
# 10                                       Modem  35.90         MARIE        1
# 11                            Les Républicains  24.52       CHARLES        1
# 12                              Front National  16.56          ANNE        1
# 13                         La France insoumise  10.74      SYLVIANE        1
# 14                                  Ecologiste   6.30        ALBANE        1
# 15                            Debout la France   2.52       PASCALE        1
# 16                   Parti communiste français   1.48           GUY        1
# 17                                      Divers   0.88      SANDRINE        1
# 18                              Extrême gauche   0.66       VINCENT        1
# 19                                      Divers   0.43         ATILA        1
# 20                                 En marche !  45.30          OLGA        1
# 21                            Les Républicains  21.41     STEPHANIE        1
# 22                              Front National  11.20        GAETAN        1
# 23                         La France insoumise   9.01     CHRISTIAN        1
# 24                                  Ecologiste   4.40          JEAN        1
# 25                            Parti socialiste   4.32     GERALDINE        1
# 26                                      Divers   1.43       THIERRY        1
# 27                   Parti communiste français   1.27          JEAN        1
# 28                                      Divers   1.06      FREDERIC        1
# 29                              Extrême gauche   0.43          ERIC        1
# ...                                        ...    ...           ...      ...
# 7549                              Régionaliste   1.06        MACATE      988
# 7550                                    Divers   0.73        MICHEL      988
# 7551                              Régionaliste  30.08         LOUIS      988
# 7552  Union des Démocrates et des Indépendants  23.94      PHILIPPE      988
# 7553                             Divers droite  15.36        HAROLD      988
# 7554                            Front National  11.69        BIANCA      988
# 7555                             Divers droite  10.00           GIL      988
# 7556                             Divers droite   6.83        PASCAL      988
# 7557                              Régionaliste   0.98         HENRY      988
# 7558                                    Divers   0.71         OSCAR      988
# 7559                                    Divers   0.41        MANUEL      988
# 7560                             Divers gauche  29.77       GABRIEL      973
# 7561                               En marche !  29.58        JOELLE      973
# 7562                             Divers gauche  10.45      JEMETREE      973
# 7563                             Divers gauche  10.40          LINE      973
# 7564                       La France insoumise   8.96        CLAIRE      973
# 7565                             Divers droite   6.15        MICHEL      973
# 7566                              Régionaliste   1.79        ARMAND      973
# 7567                              Régionaliste   1.15        SYLVIO      973
# 7568                             Divers gauche   1.04        JULIEN      973
# 7569                             Divers gauche   0.70        MICHEL      973
# 7570                                    Divers   0.01       ARLETTE      973
# 7571                               En marche !  36.44       LENAICK      973
# 7572                              Régionaliste  20.28          DAVY      973
# 7573                             Divers gauche  19.45       CHANTAL      973
# 7574                             Divers gauche   9.47  JEAN-ETIENNE      973
# 7575                             Divers gauche   5.79       RICHARD      973
# 7576                          Les Républicains   4.35       JULIANA      973
# 7577                       La France insoumise   2.44          PAUL      973
# 7578                                    Divers   1.77       BERNARD      973
#
#       prediction
# 0       0.272217
# 1       0.338142
# 2       0.173581
# 3       0.103080
# 4       0.018553
# 5       0.024628
# 6       0.021781
# 7       0.014782
# 8       0.013640
# 9       0.019595
# 10           NaN
# 11      0.334827
# 12      0.166439
# 13      0.100448
# 14      0.019628
# 15      0.032276
# 16      0.028004
# 17      0.013423
# 18      0.021089
# 19      0.018479
# 20      0.282511
# 21      0.305308
# 22      0.116768
# 23      0.118232
# 24      0.025400
# 25      0.019990
# 26      0.021511
# 27           NaN
# 28      0.021511
# 29      0.028472
# ...          ...
# 7549    0.029224
# 7550    0.029224
# 7551    0.046565
# 7552    0.320974
# 7553    0.116986
# 7554    0.141810
# 7555    0.116986
# 7556    0.116986
# 7557    0.046565
# 7558    0.046565
# 7559    0.046565
# 7560    0.320124
# 7561    0.253768
# 7562    0.051706
# 7563    0.044615
# 7564    0.061384
# 7565    0.053493
# 7566    0.037852
# 7567         NaN
# 7568    0.051706
# 7569    0.050750
# 7570    0.036749
# 7571    0.153438
# 7572    0.045880
# 7573    0.367691
# 7574    0.183357
# 7575    0.064830
# 7576    0.055056
# 7577    0.083867
# 7578    0.045880
#
# [7579 rows x 9 columns]

# %% [markdown]
# ## Merge

# %%
temp = df2.merge(pred[["nom", "prenom", "code", "prediction"]], how="left", on=["nom", "prenom", "code"])

# %%
temp.shape
# Out:
# (7579, 9)

# %% [markdown]
# ## On vire les na

# %%
temp = temp.dropna(axis=0)

# %%
temp.shape
# Out:
# (7400, 9)

# %%
temp.prediction = temp.prediction*100

# %%
np.round(temp["score"].max())
# Out:
# 60.0

# %% [markdown]
# ## Quelques indic de perfo

# %% [markdown]
# ### MAE

# %%
mae = []
gap = []
for i in range(int(temp["score"].min()), int(np.round(temp["score"].max())), 1):
    ttemp = temp[temp["score"]>i]
    gap.append(i)
    mae.append(mean_absolute_error(ttemp.prediction, ttemp.score))

# %%
plt.plot(gap, mae)
plt.xlabel("seuil de score >")
plt.ylabel("MAE")
plt.show()

# %%
mean_absolute_error(temp.prediction, temp.score)
# Out:
# 2.6506260203332035

# %% [markdown]
# ### Répartition des erreurs

# %%
temp["ecart"] = abs(temp.prediction - temp.score)

# %%
temp["ecart"].hist(bins=9)
plt.show()

# %% [markdown]
# ### R2

# %%
r2_score(temp.prediction, temp.score)
# Out:
# 0.77446561523617907

# %% [markdown]
# ## Etude des ballotages

# %%
def qualif(x):
    if x > 50:
        return "E"
    if x > 12.5:
        return "0"
    else: 
        return "N"
    
temp["qualif_true"] = temp["score"].map(lambda x : qualif(x))
temp["qualif_pred"] = temp["prediction"].map(lambda x : qualif(x))

# %%
temp[(temp["code"]=="56|4") | (temp["code"]=="75|1") | (temp["code"]=="80|5") | (temp["code"]=="972|3") | (temp["code"]=="986|1") ]
# Out:
#                  depart   code circo             nom  \
# 3417           morbihan   56|4     4           MOLAC
# 3418           morbihan   56|4     4           HERRY
# 3419           morbihan   56|4     4          BUCHET
# 3420           morbihan   56|4     4         RICHARD
# 3421           morbihan   56|4     4        LANDRIAU
# 3422           morbihan   56|4     4           CABAS
# 3423           morbihan   56|4     4          AMISSE
# 3424           morbihan   56|4     4           FELIX
# 3425           morbihan   56|4     4           RAULT
# 3426           morbihan   56|4     4            HUET
# 3427           morbihan   56|4     4         SAVELLI
# 5115              paris   75|1     1        MAILLARD
# 5116              paris   75|1     1         LEGARET
# 5117              paris   75|1     1           VERON
# 5118              paris   75|1     1           COMOY
# 5119              paris   75|1     1        BARIGANT
# 5120              paris   75|1     1          BALADI
# 5121              paris   75|1     1        COEFFIER
# 5122              paris   75|1     1              DE
# 5123              paris   75|1     1        MAZAHERI
# 5124              paris   75|1     1           BAYLE
# 5125              paris   75|1     1          GORDTS
# 5126              paris   75|1     1              DE
# 5127              paris   75|1     1              LE
# 5128              paris   75|1     1       TAVERNIER
# 5129              paris   75|1     1      QUINTERNET
# 5130              paris   75|1     1         VALLAUD
# 5131              paris   75|1     1              DE
# 5132              paris   75|1     1             DOR
# 5133              paris   75|1     1       BOULINIER
# 5134              paris   75|1     1              DE
# 5135              paris   75|1     1          MUNIER
# 5136              paris   75|1     1     LEVAVASSEUR
# 5960              somme   80|5     5         DEMILLY
# 5961              somme   80|5     5         GRIMAUX
# 5962              somme   80|5     5        SPINELLI
# 5963              somme   80|5     5         ROUSSEL
# 5964              somme   80|5     5      VINDEVOGEL
# 5965              somme   80|5     5  SOROKINA-DOLLE
# 5966              somme   80|5     5           PERDU
# 5967              somme   80|5     5        LIEVRARD
# 5968              somme   80|5     5        MAKOWSKI
# 7432        martinique_  972|3     3        LETCHIMY
# 7433        martinique_  972|3     3          CAROLE
# 7434        martinique_  972|3     3         ORVILLE
# 7435        martinique_  972|3     3       LAVENTURE
# 7436        martinique_  972|3     3             JOS
# 7437        martinique_  972|3     3          RENARD
# 7438        martinique_  972|3     3            TOUL
# 7439        martinique_  972|3     3          FAGOUR
# 7440        martinique_  972|3     3  JOACHIM-ARNAUD
# 7441        martinique_  972|3     3            GAMA
# 7442        martinique_  972|3     3       JEANVILLE
# 7443        martinique_  972|3     3          LIMERY
# 7444        martinique_  972|3     3              DE
# 7445        martinique_  972|3     3      MARGUERITE
# 7509  wallis-et-futuna_  986|1     1        POLUTELE
# 7510  wallis-et-futuna_  986|1     1           BRIAL
#
#                                          parti  score           prenom  \
# 3417                               En marche !  54.00             PAUL
# 3418                          Les Républicains  14.45     MARIE-HELENE
# 3419                       La France insoumise  12.16           CECILE
# 3420                            Front National  10.15            AGNES
# 3421                                Ecologiste   4.09         NATHALIE
# 3422                          Debout la France   1.70            DAVID
# 3423                            Extrême gauche   1.14       JEAN-LOUIS
# 3424                            Extrême droite   0.99        JEAN-PAUL
# 3425                                    Divers   0.67        CHRISTINE
# 3426                             Divers droite   0.62          BERNARD
# 3427                                Ecologiste   0.01           FRANCE
# 5115                               En marche !  50.80          SYLVAIN
# 5116                          Les Républicains  17.76    JEAN-FRANCOIS
# 5117                          Parti socialiste   7.83          PAULINE
# 5118                       La France insoumise   6.00          PATRICK
# 5119                                Ecologiste   5.24         VICTORIA
# 5120                             Divers droite   3.34          VINCENT
# 5121                            Front National   2.17         GUYLAINE
# 5122                             Divers droite   1.16              IDA
# 5123                                    Divers   0.87            MICHA
# 5124                 Parti communiste français   0.82           SYLVIE
# 5125                                    Divers   0.69         NATHALIE
# 5126                             Divers droite   0.56            LOUIS
# 5127                                    Divers   0.53            RONAN
# 5128                          Debout la France   0.47       CHRISTOPHE
# 5129                                    Divers   0.39        BERANGERE
# 5130                                Ecologiste   0.38             MARC
# 5131                                    Divers   0.34         MATHILDE
# 5132                                    Divers   0.23          JACQUES
# 5133                            Extrême gauche   0.22         LAURENCE
# 5134                             Divers droite   0.10        LOUIS-MAX
# 5135                                Ecologiste   0.08           PASCAL
# 5136                             Divers droite   0.01             ERIC
# 5960  Union des Démocrates et des Indépendants  53.77         STEPHANE
# 5961                            Front National  21.25             LOIC
# 5962                       La France insoumise  11.98          OLIVIER
# 5963                 Parti communiste français   4.88          VALERIE
# 5964                                    Divers   3.59          THIERRY
# 5965                          Debout la France   1.57             OLGA
# 5966                            Extrême droite   1.19         FLORENCE
# 5967                            Extrême gauche   1.10            REGIS
# 5968                                    Divers   0.65            DAVID
# 7432                             Divers gauche  60.17            SERGE
# 7433                              Régionaliste  16.58          FRANCIS
# 7434                                     Modem   5.34              MAX
# 7435                             Divers droite   3.84           MIGUEL
# 7436                             Divers gauche   2.62         NATHALIE
# 7437                       La France insoumise   2.51          THIERRY
# 7438                             Divers gauche   1.87     MARIE-FRANCE
# 7439                                    Divers   1.67           KAYLAN
# 7440                            Extrême gauche   1.64        GHISLAINE
# 7441                                    Divers   1.20         MATTHIEU
# 7442                            Front National   0.94     MARIE-JEANNE
# 7443                              Régionaliste   0.92            ALAIN
# 7444                                    Divers   0.37            CYRIL
# 7445  Union des Démocrates et des Indépendants   0.33  MARIE-GABRIELLE
# 7509                             Divers gauche  50.24           NAPOLE
# 7510                             Divers gauche  46.19          SYLVAIN
#
#      code_dep  prediction      ecart qualif_true qualif_pred
# 3417       56   30.758657  23.241343           E           0
# 3418       56   15.354631   0.904631           0           0
# 3419       56    9.276990   2.883010           N           N
# 3420       56   10.715009   0.565009           N           N
# 3421       56    7.875612   3.785612           N           N
# 3422       56    4.622111   2.922111           N           N
# 3423       56    3.659675   2.519675           N           N
# 3424       56    4.177894   3.187894           N           N
# 3425       56    1.156321   0.486321           N           N
# 3426       56    4.527489   3.907489           N           N
# 3427       56    7.875612   7.865612           N           N
# 5115       75   36.427066  14.372934           E           0
# 5116       75   29.905201  12.145201           0           0
# 5117       75    2.343577   5.486423           N           N
# 5118       75    5.687969   0.312031           N           N
# 5119       75    1.000529   4.239471           N           N
# 5120       75    1.600339   1.739661           N           N
# 5121       75    2.376890   0.206890           N           N
# 5122       75    1.493267   0.333267           N           N
# 5123       75    0.877644   0.007644           N           N
# 5124       75    1.620253   0.800253           N           N
# 5125       75    0.709010   0.019010           N           N
# 5126       75    1.600339   1.040339           N           N
# 5127       75    0.877644   0.347644           N           N
# 5128       75    1.674350   1.204350           N           N
# 5129       75    0.709010   0.319010           N           N
# 5130       75    1.081849   0.701849           N           N
# 5131       75    0.709010   0.369010           N           N
# 5132       75    0.877644   0.647644           N           N
# 5133       75    1.371410   1.151410           N           N
# 5134       75    1.600339   1.500339           N           N
# 5135       75    1.081849   1.001849           N           N
# 5136       75    4.374811   4.364811           N           N
# 5960       80   37.160689  16.609311           E           0
# 5961       80   29.009054   7.759054           0           0
# 5962       80   14.324958   2.344958           N           0
# 5963       80    3.738840   1.141160           N           N
# 5964       80    2.230515   1.359485           N           N
# 5965       80    4.099769   2.529769           N           N
# 5966       80    4.175499   2.985499           N           N
# 5967       80    3.030161   1.930161           N           N
# 5968       80    2.230515   1.580515           N           N
# 7432      972   31.084832  29.085168           E           0
# 7433      972   10.274278   6.305722           0           N
# 7434      972   14.456286   9.116286           N           0
# 7435      972    5.548280   1.708280           N           N
# 7436      972    6.580703   3.960703           N           N
# 7437      972    7.888881   5.378881           N           N
# 7438      972    6.580703   4.710703           N           N
# 7439      972    2.058191   0.388191           N           N
# 7440      972    2.701150   1.061150           N           N
# 7441      972    2.058191   0.858191           N           N
# 7442      972    2.640690   1.700690           N           N
# 7443      972    2.058191   1.138191           N           N
# 7444      972    2.058191   1.688191           N           N
# 7445      972    4.011433   3.681433           N           N
# 7509      986   43.349126   6.890874           E           0
# 7510      986   19.348002  26.841998           0           0

# %%
temp.loc[3418,"qualif_true"] = "N"
temp.loc[5116,"qualif_true"] = "N"
temp.loc[7433,"qualif_true"] = "N"
temp.loc[5961,"qualif_true"] = "N"
temp.loc[7510,"qualif_true"] = "N"

# %%
print(classification_report(temp["qualif_true"], temp["qualif_pred"]))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.84      0.86      0.85      1572
#           E       0.00      0.00      0.00         5
#           N       0.96      0.96      0.96      5823
#
# avg / total       0.94      0.94      0.94      7400
