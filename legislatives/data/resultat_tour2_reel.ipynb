# %%
import pandas as pd

df = pd.read_excel("comparaison_prediction_reel.xlsx", skiprows=2)
df.head()
# Out:
#    Dpt  N_circo   Code            Unnamed: 3 Unnamed: 4  \
# 0  971        1  971|1                 SERVA    Olivier
# 1  971        2  971|2                 BENIN    Justine
# 2  971        3  971|3             MATHIASIN        Max
# 3  971        4  971|4  VAINQUEUR-CHRISTOPHE     Hélène
# 4  972        1  972|1                 MANIN    Josette
#
#                        Désignation Nuance   Score Sortant Perso.  \
# 0                 M. SERVA Olivier    REM  0.6174     NaN    NaN
# 1                Mme BENIN Justine    DVG  0.6426     NaN    NaN
# 2                 M. MATHIASIN Max    DVG  0.6515     NaN    NaN
# 3  Mme VAINQUEUR-CHRISTOPHE Hélène    SOC  0.6161     NaN    NaN
# 4                Mme MANIN Josette    DVG  0.5489     NaN    NaN
#
#         ...        Accès T2 ? Elu ?  circo_leg_meme_nuance  \
# 0       ...                 O     O                    0.0
# 1       ...                 N     N                    1.0
# ...

# %%
df.columns
# Out:
# Index(['Dpt', 'N_circo', 'Code', 'Unnamed: 3', 'Unnamed: 4', 'Désignation',
#        'Nuance', 'Score', 'Sortant', 'Perso.', 'Né(e)_le', 'Profession',
#        'Tour', '% Tour 1', 'Accès T2 ?', 'Elu ?', 'circo_leg_meme_nuance',
#        'circo_pres_meme_nuance', 'score_bloc_pres', 'depute_sortant',
#        'ancien_depute', 'au_gouvernement', 'ancien_ministre',
#        'membre_majorite'],
#       dtype='object')

# %%
df = df[["Code", "Désignation", "Nuance", "Score"]]

# %%
df["Code"] = df["Code"].map(lambda x : x.replace("|", "-"))
# Out:
# C:\Users\Mohamed\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df
# Out:
#       Code                      Désignation Nuance   Score
# 0    971-1                 M. SERVA Olivier    REM  0.6174
# 1    971-2                Mme BENIN Justine    DVG  0.6426
# 2    971-3                 M. MATHIASIN Max    DVG  0.6515
# 3    971-4  Mme VAINQUEUR-CHRISTOPHE Hélène    SOC  0.6161
# 4    972-1                Mme MANIN Josette    DVG  0.5489
# 5    972-2           M. AZEROT Bruno Nestor    DVG  0.5578
# 6    972-3                M. LETCHIMY Serge    DVG  0.7394
# 7    972-4           M. NILOR Jean-Philippe    REG  0.6802
# 8    973-1              M. SERVILLE Gabriel    DVG  0.5133
# 9    973-2                  M. ADAM Lénaïck    REM  0.5021
# 10   974-1              Mme BAREIGTS Ericka    SOC  0.6586
# 11   974-2               Mme BELLO Huguette    DVG  0.7359
# 12   974-3             Mme BASSIRE Nathalie     LR  0.5644
# 13   974-4                  M. LORION David     LR  0.5439
# 14   974-5           M. RATENON Jean Hugues    DVG  0.5288
# ...

# %%
df.to_csv("resultatT2_reel.csv", index=False)

# %%
df[df.Nuance=="REG"]
# Out:
#       Code                    Désignation Nuance   Score
# 7    972-4         M. NILOR Jean-Philippe    REG  0.6802
# 23   987-3  M. BROTHERSON Moetai, Charles    REG  0.5250
# 119   2A-2        M. COLOMBANI Paul-André    REG  0.5522
# 120   2B-1           M. CASTELLANI Michel    REG  0.6081
# 121   2B-2        M. ACQUAVIVA Jean-Félix    REG  0.6316
