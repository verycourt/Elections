# %%
#!/usr/bin/python
# coding: utf-8

import sys
import requests
from datetime import date, timedelta
import pandas as pd
from bs4 import BeautifulSoup
if sys.version_info[0] == 2:
    import urllib2 as ul # Python2
else:
    import urllib.request as ul # Python3
import json

# %%
def FacebookPageData(page_id, access_token):
    
    # construct the URL string
    base = 'https://graph.facebook.com/v2.8'
    node = '/' + page_id
    parameters = '/?access_token=%s&fields=name,talking_about_count,fan_count' % access_token
    url = base + node + parameters
    
    # retrieve data
    response = ul.urlopen(url)
    data = json.loads(response.read().decode('utf-8'))
    
    print('Facebook page :', data['name'])
    return [int(data[metric]) for metric in ['fan_count', 'talking_about_count']]

def YoutubePageData(page_id, access_token):
    base = 'https://www.googleapis.com/youtube/v3/channels'
    parameters = '?part=statistics&id=' + page_id + '&key=' + access_token
    url = base + parameters
    
    # retrieve data
    response = ul.urlopen(url)
    data = json.loads(response.read().decode('utf-8'))
    statistics = data['items'][0]['statistics']

    return [int(statistics[metric]) for metric in ['subscriberCount', 'viewCount', 'videoCount']]

def YoutubeVideosData(page_id, access_token):
    base = 'https://www.googleapis.com/youtube/v3/search'
    parameters = '?order=date&part=snippet&channelId=' + page_id + '&maxResults=10&key=' + access_token
    url = base + parameters
    
    # retrieve list of the most recently published videos on the channel
    response = ul.urlopen(url)
    data = json.loads(response.read().decode('utf-8'))
    videoIds = [e['id']['videoId'] for e in data['items'] if 'videoId' in e['id']]
    
    base = 'https://www.googleapis.com/youtube/v3/videos'
    parameters = '?part=statistics&id=' + ','.join(videoIds) + '&key=' + access_token
    url = base + parameters
    
    response = ul.urlopen(url)
    data = json.loads(response.read().decode('utf-8'))
    keys = data['items'][0]['statistics'].keys() # list of metrics
    n = len(data['items'])
    
    # Construction du dictionnaire des valeurs moyennes pour chaque clé sur les vidéos analysées
    videoStats = {key: int(round(sum([int(e['statistics'][key]) for e in data['items']]) / n)) for key in keys}
    
    print('Getting average metrics for the latest', n, 'videos of the channel')

    return [videoStats[metric] for metric in ['viewCount', 'likeCount', 'dislikeCount']]

# %%
# Youtube, Facebook, Twitter, fichier .json de sauvegarde
accounts = {'Alliot-Marie': [None, 'MAlliotMarie', 'MAlliotMarie', 'MAM'],
           'Arthaud': ['UCZsh-MrJftAOP_-ZgRgLScw', 'nathaliearthaud', 'n_arthaud', 'NAR'],
           'Bayrou': [None, 'bayrou', 'bayrou', 'FBA'],
           'Cheminade': ['UCCPw8MX-JcsiTzItY-qq1Fg', 'Jcheminade', 'Jcheminade', 'JCH'],
           'Dupont-Aignan': ['UCfA5DnCDX3Ixy5QOAMGtBlA', 'nicolasdupontaignan', 'dupontaignan', 'NDA'],
           'Fillon': ['UCp1R4BFJrKw34PfUc3GDLkw', 'FrancoisFillon', 'francoisfillon', 'FFI'],
           'Hamon': ['UCcMryUp6ME3BvP2alkS1dKg', 'hamonbenoit', 'benoithamon', 'BHA'],
           'Jadot': ['UCsUMhb2ygeTSS2mXLTIDHMQ', 'yannick.jadot', 'yjadot', 'YJA'],
           'Le Pen': ['UCU3z3px1_RCqYBwrs8LJVWg', 'MarineLePen', 'MLP_officiel', 'MLP'],
           'Macron': ['UCJw8np695wqWOaKVhFjkRyg', 'EnMarche', 'enmarchefr', 'EMA'],
           'Melenchon': ['UCk-_PEY3iC6DIGJKuoEe9bw', 'JLMelenchon', 'JLMelenchon', 'JLM'],
           'Poutou': [None, 'poutou.philippe', 'PhilippePoutou', 'PPO']}

app_id = "615202351999343"
app_secret = "ea787efd843d1de746817ec6e9bf7e94"
access_token = app_id + "|" + app_secret
google_key = 'AIzaSyBkRrj_kFDUv-T76CJaI3Pd-g3v7UY4GMA'

# %%
today = date.today()
print(today)

path = 'data/' # save path
# path = '/var/www/html/duel/data/'

df = pd.DataFrame()
print('Maj du', today)

for candidate in accounts:
    print('-' * 20)
    print(candidate)
    print('-' * 20)

    stats = {}
    try: # Twitter : [tweets, following, followers]
        print('Analyzing Twitter account', accounts[candidate][2])
        soup = BeautifulSoup(requests.get('https://twitter.com/' + accounts[candidate][2] + '?lang=en').text, 'lxml')
        stats_tw = [int(tag.attrs['title'].replace(',', '').split(' ')[0])
                    for tag in soup.find_all(class_='ProfileNav-stat', limit=3) if 'title' in tag.attrs]
    except:
        stats_tw = ['-', '-', '-']

    stats['tw_tweets'], stats['tw_following'], stats['tw_followers'] = stats_tw

    if accounts[candidate][0] is not None:
        print('Scanning Youtube Channel')
        try: # Youtube [abonnés, total vues, nombre de vidéos]
            stats_yt = YoutubePageData(accounts[candidate][0], google_key)
        except:
            stats_yt = ['-', '-', '-']
        try: # Youtube [moyenne vues 5 vidéos, moyenne likes 5 vidéos, moyenne dislikes 5 vidéos]
            stats_yt2 = YoutubeVideosData(accounts[candidate][0], google_key)
        except:
            stats_yt2 = ['-', '-', '-']
    else:
        print('No Youtube Channel')
        stats_yt, stats_yt2 = [0, 0, 0], [0, 0, 0]

    stats['yt_subscribers'], stats['yt_views'], stats['yt_videos'] = stats_yt
    stats['yt_views_avg'], stats['yt_likes_avg'], stats['yt_dislikes_avg'] = stats_yt2

    try: # Facebook : [likes, people talking about this]
        stats_fb = FacebookPageData(accounts[candidate][1], access_token)
    except:
        stats_fb = ['-', '-']

    stats['fb_likes'], stats['fb_talking_about'] = stats_fb

    print()
    print('Collected data')
    print(stats)
    print()
    
    # ajout de la ligne du candidat dans le dataframe
    rec = pd.DataFrame([stats.values()], columns=stats.keys(), index=[accounts[candidate][3]])
    df = df.append(rec, verify_integrity=False)

# sauvegarde des données
df.to_json(path + str(today) + '.json', orient='split')
# Out:
# 2017-02-13
# Maj du 2017-02-13
# --------------------
# Cheminade
# --------------------
# Analyzing Twitter account Jcheminade
# Scanning Youtube Channel
# Getting average metrics for the latest 10 videos of the channel
# Facebook page : Jacques Cheminade
#
# Collected data
# {'tw_following': 137, 'tw_tweets': 6577, 'yt_dislikes_avg': 1, 'yt_views_avg': 1424, 'yt_videos': 135, 'yt_likes_avg': 17, 'yt_subscribers': 856, 'fb_likes': 5335, 'yt_views': 165292, 'fb_talking_about': 259, 'tw_followers': 3841}
#
# --------------------
# Melenchon
# --------------------
# Analyzing Twitter account JLMelenchon
# Scanning Youtube Channel
# Getting average metrics for the latest 10 videos of the channel
# Facebook page : Jean-Luc Mélenchon
#
# Collected data
# {'tw_following': 5145, 'tw_tweets': 19152, 'yt_dislikes_avg': 385, 'yt_views_avg': 194596, 'yt_videos': 394, 'yt_likes_avg': 14601, 'yt_subscribers': 212168, 'fb_likes': 650067, 'yt_views': 13380101, 'fb_talking_about': 150175, 'tw_followers': 963393}
#
# --------------------
# Poutou
# --------------------
# Analyzing Twitter account PhilippePoutou
# No Youtube Channel
# Facebook page : Philippe Poutou
#
# Collected data
# {'tw_following': 198, 'tw_tweets': 2969, 'yt_dislikes_avg': 0, 'yt_views_avg': 0, 'yt_videos': 0, 'yt_likes_avg': 0, 'yt_subscribers': 0, 'fb_likes': 10515, 'yt_views': 0, 'fb_talking_about': 1718, 'tw_followers': 96684}
#
# --------------------
# Macron
# --------------------
# Analyzing Twitter account enmarchefr
# Scanning Youtube Channel
# Getting average metrics for the latest 10 videos of the channel
# Facebook page : En Marche
#
# Collected data
# {'tw_following': 633, 'tw_tweets': 928, 'yt_dislikes_avg': 34, 'yt_views_avg': 1072, 'yt_videos': 90, 'yt_likes_avg': 43, 'yt_subscribers': 7061, 'fb_likes': 96706, 'yt_views': 589388, 'fb_talking_about': 22963, 'tw_followers': 57707}
#
# --------------------
# Arthaud
# --------------------
# Analyzing Twitter account n_arthaud
# Scanning Youtube Channel
# Getting average metrics for the latest 10 videos of the channel
# Facebook page : Nathalie Arthaud
#
# Collected data
# {'tw_following': 65, 'tw_tweets': 594, 'yt_dislikes_avg': 0, 'yt_views_avg': 192, 'yt_videos': 58, 'yt_likes_avg': 10, 'yt_subscribers': 172, 'fb_likes': 1754, 'yt_views': 10832, 'fb_talking_about': 383, 'tw_followers': 1787}
#
# --------------------
# Fillon
# --------------------
# Analyzing Twitter account francoisfillon
# Scanning Youtube Channel
# Getting average metrics for the latest 10 videos of the channel
# Facebook page : François Fillon
#
# Collected data
# {'tw_following': 2849, 'tw_tweets': 15822, 'yt_dislikes_avg': 232, 'yt_views_avg': 8753, 'yt_videos': 270, 'yt_likes_avg': 219, 'yt_subscribers': 4012, 'fb_likes': 277704, 'yt_views': 922546, 'fb_talking_about': 136594, 'tw_followers': 422401}
#
# --------------------
# Hamon
# --------------------
# Analyzing Twitter account benoithamon
# Scanning Youtube Channel
# Getting average metrics for the latest 10 videos of the channel
# Facebook page : Benoît Hamon
#
# Collected data
# {'tw_following': 2043, 'tw_tweets': 7102, 'yt_dislikes_avg': 48, 'yt_views_avg': 4581, 'yt_videos': 110, 'yt_likes_avg': 117, 'yt_subscribers': 4263, 'fb_likes': 121055, 'yt_views': 257552, 'fb_talking_about': 113317, 'tw_followers': 325899}
#
# --------------------
# Le Pen
# --------------------
# Analyzing Twitter account MLP_officiel
# Scanning Youtube Channel
# Getting average metrics for the latest 10 videos of the channel
# Facebook page : Marine Le Pen
#
# Collected data
# {'tw_following': 4088, 'tw_tweets': 12434, 'yt_dislikes_avg': 11, 'yt_views_avg': 1626, 'yt_videos': 102, 'yt_likes_avg': 134, 'yt_subscribers': 11593, 'fb_likes': 1198415, 'yt_views': 1549237, 'fb_talking_about': 222481, 'tw_followers': 1271806}
#
# --------------------
# Alliot-Marie
# --------------------
# Analyzing Twitter account MAlliotMarie
# No Youtube Channel
# Facebook page : Michèle ALLIOT-MARIE
#
# Collected data
# {'tw_following': 2116, 'tw_tweets': 1604, 'yt_dislikes_avg': 0, 'yt_views_avg': 0, 'yt_videos': 0, 'yt_likes_avg': 0, 'yt_subscribers': 0, 'fb_likes': 11872, 'yt_views': 0, 'fb_talking_about': 507, 'tw_followers': 26323}
#
# --------------------
# Bayrou
# --------------------
# Analyzing Twitter account bayrou
# No Youtube Channel
# Facebook page : François Bayrou
#
# Collected data
# {'tw_following': 2023, 'tw_tweets': 3996, 'yt_dislikes_avg': 0, 'yt_views_avg': 0, 'yt_videos': 0, 'yt_likes_avg': 0, 'yt_subscribers': 0, 'fb_likes': 69789, 'yt_views': 0, 'fb_talking_about': 11147, 'tw_followers': 548460}
#
# --------------------
# Jadot
# --------------------
# Analyzing Twitter account yjadot
# Scanning Youtube Channel
# Getting average metrics for the latest 9 videos of the channel
# Facebook page : Yannick Jadot
#
# Collected data
# {'tw_following': 1029, 'tw_tweets': 22016, 'yt_dislikes_avg': 0, 'yt_views_avg': 301, 'yt_videos': 35, 'yt_likes_avg': 11, 'yt_subscribers': 681, 'fb_likes': 24305, 'yt_views': 8105, 'fb_talking_about': 9609, 'tw_followers': 27428}
#
# --------------------
# Dupont-Aignan
# --------------------
# Analyzing Twitter account dupontaignan
# Scanning Youtube Channel
# Getting average metrics for the latest 9 videos of the channel
# Facebook page : Nicolas Dupont-Aignan
#
# Collected data
# {'tw_following': 820, 'tw_tweets': 9204, 'yt_dislikes_avg': 1, 'yt_views_avg': 826, 'yt_videos': 903, 'yt_likes_avg': 40, 'yt_subscribers': 3188, 'fb_likes': 64362, 'yt_views': 1242335, 'fb_talking_about': 8538, 'tw_followers': 87481}

# %%
a = pd.read_json('data/' + str(today) + '.json', orient='split')
a
# Out:
#      tw_following  tw_tweets  yt_dislikes_avg  yt_views_avg  yt_videos  \
# JCH           137       6577                1          1424        135
# JLM          5145      19152              385        194596        394
# PPO           198       2969                0             0          0
# EMA           633        928               34          1072         90
# NAR            65        594                0           192         58
# FFI          2849      15822              232          8753        270
# BHA          2043       7102               48          4581        110
# MLP          4088      12434               11          1626        102
# MAM          2116       1604                0             0          0
# FBA          2023       3996                0             0          0
# YJA          1029      22016                0           301         35
# NDA           820       9204                1           826        903
#
#      yt_likes_avg  yt_subscribers  fb_likes  yt_views  fb_talking_about  \
# JCH            17             856      5335    165292               259
# JLM         14601          212168    650067  13380101            150175
# PPO             0               0     10515         0              1718
# EMA            43            7061     96706    589388             22963
# NAR            10             172      1754     10832               383
# FFI           219            4012    277704    922546            136594
# BHA           117            4263    121055    257552            113317
# MLP           134           11593   1198415   1549237            222481
# MAM             0               0     11872         0               507
# FBA             0               0     69789         0             11147
# YJA            11             681     24305      8105              9609
# NDA            40            3188     64362   1242335              8538
#
#      tw_followers
# JCH          3841
# JLM        963393
# PPO         96684
# EMA         57707
# NAR          1787
# FFI        422401
# BHA        325899
# MLP       1271806
# MAM         26323
# FBA        548460
# YJA         27428
# NDA         87481
